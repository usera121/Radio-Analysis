# %% [markdown]
# # Analysis of Polish Radio Stations
#
#
# ---
#
# ## 1. Project Overview
#
# This report presents an analysis of music tracks played across 13 Polish radio stations between January 1, 2024 and June 16, 2025. The analysis covers track and artist popularity, library uniqueness, the speed at which premieres appear, and the frequency of airplay during specific times of the day.
#
# Data sources include the odsluchane.eu portal and the "musicbrainzngs" library, which provides access to the MusicBrainz database from which track release dates were obtained.
#
# **Key figures:**
# - Records analyzed: 1 835 671
# - Unique artists: 52 877
# - Unique tracks: 86 816
#
# **Key questions:**
# - Who are the most played artists and songs?
# - Which tracks are unique to specific stations?
# - How quickly do new releases appear across different radios?
# - What are the patterns of music airplay at different times of day?
# - Which radio stations are most likely to premiere songs that later become major hits?
# - How do new tracks travel from their premiere to wider popularity across the radio landscape?
#
# ---

# %% [markdown]
# ## 2. Data Loading & Environment Setup
#
# The analysis was performed in Python using the following libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import plotly.express as px
import plotly.graph_objs as go
from datetime import datetime
import os
import re

# %%
# Main dataset load
# Path to the folder with Excel files
folder_path = r"data\output_fast"

# %%
# Get all .xlsx files in the folder
all_files = glob(os.path.join(folder_path, "*.xlsx"))

print(f"Found {len(all_files)} Excel files.")
# Out:
# Found 533 Excel files.

# %%
# Read and concatenate all files into a single DataFrame
df_all = pd.concat([pd.read_excel(file) for file in all_files], ignore_index=True)

print(f"Combined DataFrame shape: {df_all.shape}")
df_all.head()
# Out:
# Combined DataFrame shape: (1838972, 6)
#   Godzina                    Nazwa utworu      Radio Data_odtworzenia  \
# 0   00:00             U2 - New Year's Day  Antyradio       2024-01-01
# 1   00:05  Jet - Are You Gonna Be My Girl  Antyradio       2024-01-01
# 2   00:09         Green Day - Basket Case  Antyradio       2024-01-01
# 3   00:12  Metallica - Whiskey In The Jar  Antyradio       2024-01-01
# 4   00:17               T.love - Warszawa  Antyradio       2024-01-01
#
#    Godzina_od  Godzina_do
# 0           0           2
# 1           0           2
# 2           0           2
# 3           0           2
# 4           0           2

# %% [markdown]
# ## 3. Data Cleaning & Preparation

# %%
# Rename columns to English
df_all = df_all.rename(columns={
    'Godzina': 'time',
    'Nazwa utworu': 'track',
    'Radio': 'station',
    'Data_odtworzenia': 'date',
    'Godzina_od': 'hour_from',
    'Godzina_do': 'hour_to'
})

# %%
df_all.head()
# Out:
#     time                           track    station        date  hour_from  \
# 0  00:00             U2 - New Year's Day  Antyradio  2024-01-01          0
# 1  00:05  Jet - Are You Gonna Be My Girl  Antyradio  2024-01-01          0
# 2  00:09         Green Day - Basket Case  Antyradio  2024-01-01          0
# 3  00:12  Metallica - Whiskey In The Jar  Antyradio  2024-01-01          0
# 4  00:17               T.love - Warszawa  Antyradio  2024-01-01          0
#
#    hour_to
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
# Check for missing values
missing_summary = df_all.isnull().sum()
print("Missing values per column:\n", missing_summary)
# Out:
# Missing values per column:
#  time         0
# track        0
# station      0
# date         0
# hour_from    0
# hour_to      0
# dtype: int64

# %%
# Check for duplicates
duplicates = df_all.duplicated()
num_duplicates = duplicates.sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 1196

# %%
# Show column data types
print(df_all.dtypes)
# Out:
# time         object
# track        object
# station      object
# date         object
# hour_from     int64
# hour_to       int64
# dtype: object

# %%
# Convert date column to datetime
df_all['date'] = pd.to_datetime(df_all['date'], errors='coerce')

# Convert time column to time (format HH:MM)
df_all['time'] = pd.to_datetime(df_all['time'], format='%H:%M', errors='coerce').dt.time

print(df_all.dtypes)
df_all.head()
# Out:
# time                 object
# track                object
# station              object
# date         datetime64[ns]
# hour_from             int64
# hour_to               int64
# dtype: object
#        time                           track    station       date  hour_from  \
# 0  00:00:00             U2 - New Year's Day  Antyradio 2024-01-01          0
# 1  00:05:00  Jet - Are You Gonna Be My Girl  Antyradio 2024-01-01          0
# 2  00:09:00         Green Day - Basket Case  Antyradio 2024-01-01          0
# 3  00:12:00  Metallica - Whiskey In The Jar  Antyradio 2024-01-01          0
# 4  00:17:00               T.love - Warszawa  Antyradio 2024-01-01          0
#
#    hour_to
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
# Split 'track' column into 'artist' and 'title'
df_all[['artist', 'title']] = df_all['track'].str.extract(r'^(.*?)\s*-\s*(.*)$')
df_all
# Out:
#              time                                 track         station  \
# 0        00:00:00                   U2 - New Year's Day       Antyradio
# 1        00:05:00        Jet - Are You Gonna Be My Girl       Antyradio
# 2        00:09:00               Green Day - Basket Case       Antyradio
# 3        00:12:00        Metallica - Whiskey In The Jar       Antyradio
# 4        00:17:00                     T.love - Warszawa       Antyradio
# ...           ...                                   ...             ...
# 1838967  23:42:00                     Bon Jovi - Always  Złote Przeboje
# 1838968  23:47:00         K.a.s.a. & Los Amigos - Maczo  Złote Przeboje
# 1838969  23:50:00  Modern Talking - Geronimo's Cadillac  Złote Przeboje
# 1838970  23:54:00     Budka Suflera - Ratujmy Co Sie Da  Złote Przeboje
# 1838971  23:58:00              De Su - Zycie Cudem Jest  Złote Przeboje
#
#               date  hour_from  hour_to                 artist  \
# 0       2024-01-01          0        2                     U2
# 1       2024-01-01          0        2                    Jet
# 2       2024-01-01          0        2              Green Day
# 3       2024-01-01          0        2              Metallica
# 4       2024-01-01          0        2                 T.love
# ...            ...        ...      ...                    ...
# 1838967 2025-06-16         22        0               Bon Jovi
# 1838968 2025-06-16         22        0  K.a.s.a. & Los Amigos
# 1838969 2025-06-16         22        0         Modern Talking
# 1838970 2025-06-16         22        0          Budka Suflera
# 1838971 2025-06-16         22        0                  De Su
#
#                             title
# 0                  New Year's Day
# 1        Are You Gonna Be My Girl
# 2                     Basket Case
# 3              Whiskey In The Jar
# 4                        Warszawa
# ...                           ...
# 1838967                    Always
# 1838968                     Maczo
# 1838969       Geronimo's Cadillac
# 1838970         Ratujmy Co Sie Da
# 1838971          Zycie Cudem Jest
#
# [1838972 rows x 8 columns]

# %%
# Check the top artists
print(df_all['artist'].value_counts().head(20))

# there is missing artist name in 5128 records
# Out:
# artist
# Dua Lipa             8770
# Sanah                8373
# Daria Zawiałow       7381
# Dawid Podsiadło      7255
# Oskar Cyms           6944
# Sylwia Grzeszczak    6869
# Lady Gaga            6316
# Lady Pank            5789
# The Kolors           5726
#                      5128
# Teddy Swims          5041
# Ed Sheeran           4895
# Ava Max              4606
# Margaret             4522
# Maanam               4520
# Rihanna              4428
# Queen                4379
# Perfect              4334
# Wilki                4163
# Katy Perry           4117
# Name: count, dtype: int64

# %%
# Preview some rows with missing artist
df_all[df_all['artist'].str.strip() == ''][['track']].head(10)
# Out:
#                                                      track
# 52687                             - C-Bool - Magic Symphon
# 592493                             - Sofya - Back To Black
# 748468   ---__--___ More Eaze Proxy.exe & Seth Graham -...
# 748469   ---__--___ Koeosaeme More Eaze & Seth Graham -...
# 1029719  - ̟̞̝̜̙̘̗̖҉̵̴̨̧̢̡̼̻̺ - 01 ʅ͡͡͡͡͡͡͡͡͡͡͡(̸̢̛̼̞̭͋...
# 1322843                  - _String Quartet No 7 In D, D.94
# 1322844  - 999D588A_String Quartet No 7 In F, Op 59 No ...
# 1322845             - _Clarinet Quintet In B Minor, Op 115
# 1322846        - _Symphony In C Minor, _Symphonie Funebre_
# 1322847                              - _Der Pilgrim, D.794

# %%
# Checking a row with a strange value in the track column (index 1029719)
df_all.loc[1029719]
# Out:
# time                                                  22:31:00
# track        - ̟̞̝̜̙̘̗̖҉̵̴̨̧̢̡̼̻̺ - 01 ʅ͡͡͡͡͡͡͡͡͡͡͡(̸̢̛̼̞̭͋...
# station                                              Chillizet
# date                                       2024-10-29 00:00:00
# hour_from                                                   22
# hour_to                                                      0
# artist
# title        ̟̞̝̜̙̘̗̖҉̵̴̨̧̢̡̼̻̺ - 01 ʅ͡͡͡͡͡͡͡͡͡͡͡(̸̢̛̼̞̭͋Ι)...
# Name: 1029719, dtype: object

# %%
# Removing row (index 1029719)
df_all = df_all.drop(index=1029719)

# %%
# Cleaning prefixes in track names
def clean_prefix(name):
    """
    Removes any prefix in the track name up to the first letter or digit,
    including Polish diacritics.
    """
    if pd.isna(name):
        return name
    match = re.search(r'[A-Za-z0-9ĄąĆćĘęŁłŃńÓóŚśŹźŻż]', name)
    return name[match.start():] if match else name

# Clean prefixes in the 'track' column
df_all['track'] = df_all['track'].apply(clean_prefix)

# %%
# Checking again rows with missing artist
df_all[df_all['artist'].str.strip() == ''][['track']].head(10)
# Out:
#                                                      track
# 52687                               C-Bool - Magic Symphon
# 592493                               Sofya - Back To Black
# 748468   More Eaze Proxy.exe & Seth Graham - Rock Botto...
# 748469   Koeosaeme More Eaze & Seth Graham - To Suppres...
# 1322843                     String Quartet No 7 In D, D.94
# 1322844  999D588A_String Quartet No 7 In F, Op 59 No 1 ...
# 1322845                Clarinet Quintet In B Minor, Op 115
# 1322846           Symphony In C Minor, _Symphonie Funebre_
# 1322847                                 Der Pilgrim, D.794
# 1322848        4 Sea Interludes From _Peter Grimes_ Op 33A

# %%
# Removing columns artist, title, hour_from	hour_to
df_all = df_all.drop(columns=['artist', 'title', 'hour_from','hour_to'])
df_all
# Out:
#              time                                 track         station  \
# 0        00:00:00                   U2 - New Year's Day       Antyradio
# 1        00:05:00        Jet - Are You Gonna Be My Girl       Antyradio
# 2        00:09:00               Green Day - Basket Case       Antyradio
# 3        00:12:00        Metallica - Whiskey In The Jar       Antyradio
# 4        00:17:00                     T.love - Warszawa       Antyradio
# ...           ...                                   ...             ...
# 1838967  23:42:00                     Bon Jovi - Always  Złote Przeboje
# 1838968  23:47:00         K.a.s.a. & Los Amigos - Maczo  Złote Przeboje
# 1838969  23:50:00  Modern Talking - Geronimo's Cadillac  Złote Przeboje
# 1838970  23:54:00     Budka Suflera - Ratujmy Co Sie Da  Złote Przeboje
# 1838971  23:58:00              De Su - Zycie Cudem Jest  Złote Przeboje
#
#               date
# 0       2024-01-01
# 1       2024-01-01
# 2       2024-01-01
# 3       2024-01-01
# 4       2024-01-01
# ...            ...
# 1838967 2025-06-16
# 1838968 2025-06-16
# 1838969 2025-06-16
# 1838970 2025-06-16
# 1838971 2025-06-16
#
# [1838971 rows x 4 columns]

# %%
# Re-extract artist and title columns from the cleaned track
df_all[['artist', 'title']] = df_all['track'].str.extract(r'^(.*?)\s*-\s*(.*)$')
df_all
# Out:
#              time                                 track         station  \
# 0        00:00:00                   U2 - New Year's Day       Antyradio
# 1        00:05:00        Jet - Are You Gonna Be My Girl       Antyradio
# 2        00:09:00               Green Day - Basket Case       Antyradio
# 3        00:12:00        Metallica - Whiskey In The Jar       Antyradio
# 4        00:17:00                     T.love - Warszawa       Antyradio
# ...           ...                                   ...             ...
# 1838967  23:42:00                     Bon Jovi - Always  Złote Przeboje
# 1838968  23:47:00         K.a.s.a. & Los Amigos - Maczo  Złote Przeboje
# 1838969  23:50:00  Modern Talking - Geronimo's Cadillac  Złote Przeboje
# 1838970  23:54:00     Budka Suflera - Ratujmy Co Sie Da  Złote Przeboje
# 1838971  23:58:00              De Su - Zycie Cudem Jest  Złote Przeboje
#
#               date                 artist                     title
# 0       2024-01-01                     U2            New Year's Day
# 1       2024-01-01                    Jet  Are You Gonna Be My Girl
# 2       2024-01-01              Green Day               Basket Case
# 3       2024-01-01              Metallica        Whiskey In The Jar
# 4       2024-01-01                 T.love                  Warszawa
# ...            ...                    ...                       ...
# 1838967 2025-06-16               Bon Jovi                    Always
# 1838968 2025-06-16  K.a.s.a. & Los Amigos                     Maczo
# 1838969 2025-06-16         Modern Talking       Geronimo's Cadillac
# 1838970 2025-06-16          Budka Suflera         Ratujmy Co Sie Da
# 1838971 2025-06-16                  De Su          Zycie Cudem Jest
#
# [1838971 rows x 6 columns]

# %%
# Preview rows with missing artist
df_all[df_all['artist'].str.strip() == ''][['track']].head(10)
# Out:
#         track
# 1334078     -

# %%
# Checking row index 1334078
df_all.loc[1334078]
# Out:
# time                  22:08:00
# track                        -
# station                Jedynka
# date       2025-01-26 00:00:00
# artist
# title
# Name: 1334078, dtype: object

# %%
# Removing row (index 1334078)
df_all = df_all.drop(index=1334078)

# %%
# Sample rows where the song title contains a dash
sample_with_dash = df_all[df_all['title'].str.contains("-", na=False)][['track', 'artist', 'title']].sample(50)
sample_with_dash
# Out:
#                                                      track  \
# 1695651  Ignacy Jan Paderewski - Koncert Fortepianowy A...
# 1111937         Jo Yeong-Wook - Sympathy For Lady Vegeance
# 84963            Jiri Antonin Benda - 8 Symfonia D-Dur (1)
# 1833960   Clean Bandit / Sean Paul / Anne-Marie - Rockabye
# 1727374   Clean Bandit & Sean Paul & Anne-Marie - Rockabye
# 229915                Vangelis - Blade Runner - Love Theme
# 476181   Suk Praga Op 26 Bbc Symphony Orchestra Belohla...
# 11349                                      H-Blockx - Move
# 943696            Muzio Clementi - Symfonia Nr 3 G-Dur (4)
# 523537                    Franz Schubert - Oktet F-Dur (3)
# 520006   Benjamin Britten - The Young Person"s Guide To...
# 1709257  Schubert Moments Musicaux D. 780 Iii Allegro M...
# 1237384                                  A-Ha - Take On Me
# 292828                        O - Zone - Dragostea Din Tei
# 1011208  Clean Bandit / Anne-Marie / David Guetta - Cry...
# 557663                 Garou - Reviens (Ou Te Chaches-Tu?)
# 1384420  Vikingur Olafsson / Jean-Philippe Rameau - Men...
# 1267012  Offenbach Couplets De La Poupee Les Oiseaux Da...
# 1302057  Schubert Schwanengesang D 957 - 9 Ihr Bild Pad...
# 289317   Robert Schumann - Koncert Fortepianowy A-Moll (2)
# 919629   Vikingur Olafsson / Jean-Philippe Rameau - Men...
# 406339   Gigi D'agostino & Boostedkids - Shadows Of The...
# 659968   Dubois Chansons De Marjolie En Paradis Gens Mu...
# 174657   Jaga Jazzist - One-Armed Bandit ( Live With Br...
# 1695775  Antonio Vivaldi - L"estro Armonico Op.3 - Conc...
# 1377083        Remady & Manu - L & J - Son - Single Ladies
# 1673534    Lang Lang / Fryderyk Chopin - Walc Es-Dur Op.18
# 1617             Jo Yeong-Wook - From Whom The Bells Tolls
# 212126   Płyta Tygodnia Williams Luke I Leja Z Gwiezdny...
# 1034089           Muzio Clementi - Symfonia Nr 3 G-Dur (4)
# 1241893  Kosi, Szczur Jwp - To Wydarzyło Się Naprawdę -...
# 453544   Georg-Philipp Telemann - Koncert Na Trąbkę D-D...
# 1105294  Giuseppe Valentini - Koncert A-Moll No.11 Na C...
# 1757314              Thibault Cauvin, -M- - L'heure Miroir
# 1716306  Beethoven Symfonia Nr 8 F-Dur Cz Ii Saarbrucke...
# 944045   Clean Bandit / Anne-Marie / David Guetta - Cry...
# 932701       Anna Sroka-Hryń - W Dziką Jabłoń Cię Zaklęłam
# 1486720  Wzgórze Ya-Pa 3 - Bezcenne Słowa (Ft. Jarecki)...
# 673758              Franz Schubert - Vi Symfonia C-Dur (3)
# 1738608     Maurizio Pollini - Preludium E-Moll Op.28 Nr 4
# 1189047  Monika Borzym Oraz T-Raperzy Znad Wisły - Kied...
# 348209   Bartek Królik - Ręka (Feat. Szałowy Piotrek - ...
# 803523   Sophie Ellis-Bextor / Pnau - Murder On The Dan...
# 1486928  Saint-Saens Iii Koncert Fortepianowy Es-Dur Op...
# 1572493  Price Kwintet Fortepianowy A-Moll - Takács Qua...
# 1468754      Mura Masa - E-Motions (Feat. Erika De Casier)
# 197789   Haendel Sonata D-Dur Op 1 Nr 13 Hwv 371 Cicic ...
# 1279267       C-Bool / Giang Pham - Dj Is Your Second Name
# 858684   Bach Pasja Mateuszowa Bwv 244 Crook The Englis...
# 369646   Wojciech Kilar - Giuseppe W Warszawie X - Wojc...
#
#                                                     artist  \
# 1695651                              Ignacy Jan Paderewski
# 1111937                                           Jo Yeong
# 84963                                   Jiri Antonin Benda
# 1833960                    Clean Bandit / Sean Paul / Anne
# 1727374                    Clean Bandit & Sean Paul & Anne
# 229915                                            Vangelis
# 476181   Suk Praga Op 26 Bbc Symphony Orchestra Belohlavek
# 11349                                                    H
# 943696                                      Muzio Clementi
# 523537                                      Franz Schubert
# 520006                                    Benjamin Britten
# 1709257  Schubert Moments Musicaux D. 780 Iii Allegro M...
# 1237384                                                  A
# 292828                                                   O
# 1011208                                Clean Bandit / Anne
# 557663                                               Garou
# 1384420                           Vikingur Olafsson / Jean
# 1267012  Offenbach Couplets De La Poupee Les Oiseaux Da...
# 1302057                      Schubert Schwanengesang D 957
# 289317                                     Robert Schumann
# 919629                            Vikingur Olafsson / Jean
# 406339                       Gigi D'agostino & Boostedkids
# 659968   Dubois Chansons De Marjolie En Paradis Gens Mu...
# 174657                                        Jaga Jazzist
# 1695775                                    Antonio Vivaldi
# 1377083                                      Remady & Manu
# 1673534                        Lang Lang / Fryderyk Chopin
# 1617                                              Jo Yeong
# 212126   Płyta Tygodnia Williams Luke I Leja Z Gwiezdny...
# 1034089                                     Muzio Clementi
# 1241893                                   Kosi, Szczur Jwp
# 453544                                               Georg
# 1105294                                 Giuseppe Valentini
# 1757314                                   Thibault Cauvin,
# 1716306                          Beethoven Symfonia Nr 8 F
# 944045                                 Clean Bandit / Anne
# 932701                                          Anna Sroka
# 1486720                                         Wzgórze Ya
# 673758                                      Franz Schubert
# 1738608                                   Maurizio Pollini
# 1189047                               Monika Borzym Oraz T
# 348209                                       Bartek Królik
# 803523                                        Sophie Ellis
# 1486928                                              Saint
# 1572493                       Price Kwintet Fortepianowy A
# 1468754                                          Mura Masa
# 197789                                    Haendel Sonata D
# 1279267                                                  C
# 858684   Bach Pasja Mateuszowa Bwv 244 Crook The Englis...
# 369646                                      Wojciech Kilar
#
#                                                      title
# 1695651                    Koncert Fortepianowy A-Moll (3)
# 1111937                  Wook - Sympathy For Lady Vegeance
# 84963                                 8 Symfonia D-Dur (1)
# 1833960                                   Marie - Rockabye
# 1727374                                   Marie - Rockabye
# 229915                           Blade Runner - Love Theme
# 476181             Praga Op. 26 Cz 2 - Allegro - Piu Mosso
# 11349                                        Blockx - Move
# 943696                             Symfonia Nr 3 G-Dur (4)
# 523537                                     Oktet F-Dur (3)
# 520006   The Young Person"s Guide To The Orchestra - Wa...
# 1709257  047 Hmx2904091.96 - Paul Lewis - 06 - 07 - Mom...
# 1237384                                    Ha - Take On Me
# 292828                            Zone - Dragostea Din Tei
# 1011208                    Marie / David Guetta - Cry Baby
# 557663                         Reviens (Ou Te Chaches-Tu?)
# 1384420                    Philippe Rameau - Menuets 1 & 2
# 1267012  Les Contes D'hoffmann - Couplets De La Poupee ...
# 1302057  9 Ihr Bild Padmore Uchida - Schwanengesang D 9...
# 289317                     Koncert Fortepianowy A-Moll (2)
# 919629                     Philippe Rameau - Menuets 1 & 2
# 406339                 Shadows Of The Night - Gigi Dag Mix
# 659968   05 - Theodore Dubois - Chansons De Marjolie En...
# 174657     One-Armed Bandit ( Live With Britten Sinfonia )
# 1695775  L"estro Armonico Op.3 - Concerto No.6 In A Min...
# 1377083                        L & J - Son - Single Ladies
# 1673534                                  Walc Es-Dur Op.18
# 1617                      Wook - From Whom The Bells Tolls
# 212126   Płyta Tygodnia Luke And Leia (From Star Wars E...
# 1034089                            Symfonia Nr 3 G-Dur (4)
# 1241893  To Wydarzyło Się Naprawdę - Oprócz Tego, Co Zm...
# 453544      Philipp Telemann - Koncert Na Trąbkę D-Dur (4)
# 1105294  Koncert A-Moll No.11 Na Czworo Skrzypiec (Presto,
# 1757314                                M- - L'heure Miroir
# 1716306  Dur Cz Ii Saarbrucken Ra - Symfonia Nr 8 F-Dur...
# 944045                     Marie / David Guetta - Cry Baby
# 932701                  Hryń - W Dziką Jabłoń Cię Zaklęłam
# 1486720  Pa 3 - Bezcenne Słowa (Ft. Jarecki) (Dj Brk X ...
# 673758                               Vi Symfonia C-Dur (3)
# 1738608                        Preludium E-Moll Op.28 Nr 4
# 1189047              Raperzy Znad Wisły - Kiedy Pada Śnieg
# 348209                Ręka (Feat. Szałowy Piotrek - Remix)
# 803523   Bextor / Pnau - Murder On The Dancefloor (Pnau...
# 1486928  Saens Iii Koncert Fortepianowy Es-Dur Op 29 - ...
# 1572493  Moll - Takács Quartet - Kwintet Fortepianowy A...
# 1468754                  E-Motions (Feat. Erika De Casier)
# 197789   Dur Op 1 Nr 13 Hwv 371 Cicic Devine - Sonata D...
# 1279267         Bool / Giang Pham - Dj Is Your Second Name
# 858684   Pasja Mateuszowa Bwv 244 - No.20 Aria (Tenor, ...
# 369646   Giuseppe W Warszawie X - Wojciech Kilar - Gius...

# %%
# Changing columns order
desired_order = ['date', 'time', 'station', 'track', 'artist', 'title']
df_all = df_all[desired_order]

df_all.head()
# Out:
#         date      time    station                           track     artist  \
# 0 2024-01-01  00:00:00  Antyradio             U2 - New Year's Day         U2
# 1 2024-01-01  00:05:00  Antyradio  Jet - Are You Gonna Be My Girl        Jet
# 2 2024-01-01  00:09:00  Antyradio         Green Day - Basket Case  Green Day
# 3 2024-01-01  00:12:00  Antyradio  Metallica - Whiskey In The Jar  Metallica
# 4 2024-01-01  00:17:00  Antyradio               T.love - Warszawa     T.love
#
#                       title
# 0            New Year's Day
# 1  Are You Gonna Be My Girl
# 2               Basket Case
# 3        Whiskey In The Jar
# 4                  Warszawa

# %%
# Sample rows where the song title contains a dash
sample_with_dash = df_all[df_all['title'].str.contains("-", na=False)][['track', 'artist', 'title']].sample(50)
sample_with_dash
# Out:
#                                                      track  \
# 1108901  James Horner - Becoming One Of The People - Be...
# 422990      Disturbed - The Sound Of Silence - Cyril Remix
# 1020255    Pitbull & Ne-Yo & Afrojack - Give Me Everything
# 255966   Sophie Ellis-Bextor / Pnau - Murder On The Dan...
# 884585          Strachy Na Lachy - Btw - Mamy Tylko Siebie
# 1040895         Francois Couperin - Vii Koncert G-Moll (4)
# 1288626  Adam Czerwiński / Jan Sebastian Bach - “Aria” ...
# 9045       Antonio Vivaldi - Cztery Pory Roku - Wiosna (3)
# 702355   Higdon Soliloquy Walters, Rose, Zehngut, Zakan...
# 1235499      Franz Joseph Haydn - Symfonia Nr 94 G-Dur (4)
# 885320   Bach Partita C-Moll Bwv 826 Anderszewski - Par...
# 1655742  Robert Schumann - Koncert Fortepianowy A-Moll (2)
# 34541    Robert Schumann - Koncert Fortepianowy A-Moll (2)
# 1819661  Moniuszko Kwartet Smyczkow D Moll Messages Qua...
# 615038   Vikingur Olafsson / Jean-Philippe Rameau - Mus...
# 1391726  Giuseppe Valentini - Koncert Skrzypcowy No.1 A...
# 240629   Sophie Ellis-Bextor / Pnau - Murder On The Dan...
# 686128   Schubert Drei Klavierstuecke D 946 - 1 Allegro...
# 199572     Pitbull & Ne-Yo & Afrojack - Give Me Everything
# 367626   Sophie Ellis-Bextor / Pnau - Murder On The Dan...
# 243920   Wolfgang Amadeusz Mozart - Symfonia Nr 41 C-Du...
# 1295290   Clean Bandit & Sean Paul & Anne-Marie - Rockabye
# 1544655           John Barry - You Only Live Twice - Theme
# 1275210  Sophie Ellis-Bextor / Pnau - Murder On The Dan...
# 476864                Jan Sebastian Bach - Preludium C-Dur
# 1355907         Jo Yeong-Wook - Sympathy For Lady Vegeance
# 135389        C-Bool / Giang Pham - Dj Is Your Second Name
# 67772    David Guetta / Anne-Marie / Coi Leray - Baby D...
# 791550   Grieg Koncert Fortepianowy A-Moll Op 16 Cz Iii...
# 1569036                  Jay-Z & Mr Hudson - Young Forever
# 1760324                    Stevie Wonder - Part-Time Lover
# 978706               Anne-Marie / Shania Twain - Unhealthy
# 1061356  Shigeru Umebayashi - Yumeji"s Theme / Mo-Wan"s...
# 807944   Del-M - Puść Plejlistę (Ft. Jan Załęski & Karo...
# 1308246       Camille Saint-Saens - Karnawal Zwierzat (12)
# 327181   Beethoven Iv Symfonia B-Dur Op. 60 - 2 Adagio ...
# 357301                    Pharell Williams - Happy - Happy
# 814585              Joan As Police Woman - Full-Time Heist
# 21158                      Eagle-Eye Cherry - Save Tonight
# 1151355             Denzel Curry - Troubles (Feat. T-Pain)
# 732788     Sheku Kanneh-Mason / Frank Bridge - Spring Song
# 1131839                       O - Zone - Dragostea Din Tei
# 745182   Franck Sonata Skrzypcowa A-Dur Fwv 8 Papavrami...
# 800060   Gigi D'agostino & Boostedkids - Shadows Of The...
# 1125286  Georg-Philipp Telemann - Koncert Na Trąbkę D-D...
# 19926                       Jean-Francois Dandrieu - Rondo
# 1254439                            T-Pain / Flo Rida - Low
# 951145            S.p.y - Together With Ukraine - Need You
# 1523643  Sanah / Krzysztof Zalewski - Eviva L"Arte! (K....
# 897362   Laback & Alexis Carlier - Titanic X My Heart W...
#
#                                                     artist  \
# 1108901                                       James Horner
# 422990                                           Disturbed
# 1020255                                       Pitbull & Ne
# 255966                                        Sophie Ellis
# 884585                                    Strachy Na Lachy
# 1040895                                  Francois Couperin
# 1288626               Adam Czerwiński / Jan Sebastian Bach
# 9045                                       Antonio Vivaldi
# 702355   Higdon Soliloquy Walters, Rose, Zehngut, Zakan...
# 1235499                                 Franz Joseph Haydn
# 885320                                      Bach Partita C
# 1655742                                    Robert Schumann
# 34541                                      Robert Schumann
# 1819661  Moniuszko Kwartet Smyczkow D Moll Messages Qua...
# 615038                            Vikingur Olafsson / Jean
# 1391726                                 Giuseppe Valentini
# 240629                                        Sophie Ellis
# 686128                  Schubert Drei Klavierstuecke D 946
# 199572                                        Pitbull & Ne
# 367626                                        Sophie Ellis
# 243920                            Wolfgang Amadeusz Mozart
# 1295290                    Clean Bandit & Sean Paul & Anne
# 1544655                                         John Barry
# 1275210                                       Sophie Ellis
# 476864                                  Jan Sebastian Bach
# 1355907                                           Jo Yeong
# 135389                                                   C
# 67772                                  David Guetta / Anne
# 791550                        Grieg Koncert Fortepianowy A
# 1569036                                                Jay
# 1760324                                      Stevie Wonder
# 978706                                                Anne
# 1061356                                 Shigeru Umebayashi
# 807944                                                 Del
# 1308246                                      Camille Saint
# 327181                             Beethoven Iv Symfonia B
# 357301                                    Pharell Williams
# 814585                                Joan As Police Woman
# 21158                                                Eagle
# 1151355                                       Denzel Curry
# 732788                                        Sheku Kanneh
# 1131839                                                  O
# 745182                          Franck Sonata Skrzypcowa A
# 800060                       Gigi D'agostino & Boostedkids
# 1125286                                              Georg
# 19926                                                 Jean
# 1254439                                                  T
# 951145                                               S.p.y
# 1523643                         Sanah / Krzysztof Zalewski
# 897362                             Laback & Alexis Carlier
#
#                                                      title
# 1108901  Becoming One Of The People - Becoming One With...
# 422990                  The Sound Of Silence - Cyril Remix
# 1020255                 Yo & Afrojack - Give Me Everything
# 255966   Bextor / Pnau - Murder On The Dancefloor (Pnau...
# 884585                             Btw - Mamy Tylko Siebie
# 1040895                             Vii Koncert G-Moll (4)
# 1288626          “Aria” - From Goldberg Variations Bwv 988
# 9045                         Cztery Pory Roku - Wiosna (3)
# 702355                      06 - Jennifer Higdon Soliloquy
# 1235499                           Symfonia Nr 94 G-Dur (4)
# 885320   Moll Bwv 826 Anderszewski - Partita C-Moll Bwv...
# 1655742                    Koncert Fortepianowy A-Moll (2)
# 34541                      Koncert Fortepianowy A-Moll (2)
# 1819661     Kwartet Smyczkowy D-Moll Cz. I Allegro Agitato
# 615038                Philippe Rameau - Musette En Rondeau
# 1391726              Koncert Skrzypcowy No.1 A-Dur(Vivace)
# 240629   Bextor / Pnau - Murder On The Dancefloor (Pnau...
# 686128   1 Allegro Assai Lewis - Drei Klavierstuecke D ...
# 199572                  Yo & Afrojack - Give Me Everything
# 367626   Bextor / Pnau - Murder On The Dancefloor (Pnau...
# 243920                  Symfonia Nr 41 C-Dur Jowiszowa (1)
# 1295290                                   Marie - Rockabye
# 1544655                        You Only Live Twice - Theme
# 1275210  Bextor / Pnau - Murder On The Dancefloor (Pnau...
# 476864                                     Preludium C-Dur
# 1355907                  Wook - Sympathy For Lady Vegeance
# 135389          Bool / Giang Pham - Dj Is Your Second Name
# 67772               Marie / Coi Leray - Baby Don"t Hurt Me
# 791550   Moll Op 16 Cz Iii Allegro Moderato E Marcato A...
# 1569036                      Z & Mr Hudson - Young Forever
# 1760324                                    Part-Time Lover
# 978706                    Marie / Shania Twain - Unhealthy
# 1061356                 Yumeji"s Theme / Mo-Wan"s Dialogue
# 807944   M - Puść Plejlistę (Ft. Jan Załęski & Karolina...
# 1308246                     Saens - Karnawal Zwierzat (12)
# 327181   Dur Op. 60 - 2 Adagio Kavakos Yo-Yo Ma Ax - Iv...
# 357301                                       Happy - Happy
# 814585                                     Full-Time Heist
# 21158                            Eye Cherry - Save Tonight
# 1151355                            Troubles (Feat. T-Pain)
# 732788                  Mason / Frank Bridge - Spring Song
# 1131839                           Zone - Dragostea Din Tei
# 745182   Dur Fwv 8 Papavrami Goerner - Sonata Skrzypcow...
# 800060                 Shadows Of The Night - Gigi Dag Mix
# 1125286     Philipp Telemann - Koncert Na Trąbkę D-Dur (4)
# 19926                            Francois Dandrieu - Rondo
# 1254439                              Pain / Flo Rida - Low
# 951145                    Together With Ukraine - Need You
# 1523643                Eviva L"Arte! (K. Przerwa-Tetmajer)
# 897362      Titanic X My Heart Will Go On - Summer Version

# %% [markdown]
# > **Improved title and artist extraction:**
# > We use a custom function that checks if the track starts with a known artist name containing a dash (from a whitelist of common cases).
# > For these, we keep the full artist name; otherwise, we split on the first dash as usual.
# > This minimizes incorrect splits and improves data quality.

# %%
artist_exceptions = [
    "Jay-Z", "C-Bool", "Anne-Marie", "Seong-Jin Cho", "Sophie Ellis-Bextor", "In - Grid",
    "Camille Saint-Saens", "Del-M", "Jean-Francois Dandrieu", "(G)I-Dle",
    "Heitor Villa-Lobos", "Czarno-Czarni", "T-Pain", "In-Grid", "Jo Yeong-Wook", "Di-Rect", "Remady & Manu - L & J - Son", "Jon Cutler Feat.E-Man", "N-Joi", "K-Lone", "The B-52's",
    "Harry Gregson-Williams", "Georg-Philipp Telemann", "A-Ha", "Ne-Yo", "Remady / Manu-L","Wu - Tang Clan", "Marc-Antoine Charpentier", "Melcer-Szczawiński", "Blink-182", "Lin-Manuel Miranda", "Paul Leonard-Morgan", "Dick Dale & His Del-Tones", "Alan Walker / Jvke / (G)I-Dle / Yuqi", "Billen Ted, Kah-Lo", "Jean-Baptiste Lully", "Sheku Kanneh-Mason", "Vikingur Olafsson / Jean-Philippe Rameau", "Sofi Tukker & Kah-Lo", "Georg-Philipp Telemann", "H-Blockx", "Sheku Kanneh-Mason / Frank Bridge", "B-Qll", "Wzgórze Ya-Pa 3", "Di-Rect",
    "Remady & Manu-L", "O - Zone", "Anne-Sophie Versnaeyen", "Eagle-Eye Cherry", "K-Maro","D-Bomb","Anne-Sophie Mutter", "Riton & Kah-Lo", "Alex C & Y-Ass", "Jan-Rapowanie & Szpaku", "One-T & Cool-T", "Jan-Rapowanie", "Nikołaj Rimski-Korsakow", "Antek-Smykiewicz", "Olivia Newton-John & John Travolta", "Beyonce & Jay - Z", "Jay - Z"

]

def extract_artist_title(track):
    if pd.isna(track):
        return pd.Series(['', track])
    last_dash = track.rfind(' - ')
    if last_dash == -1:
        return pd.Series(['', track])
    artist_part = track[:last_dash]
    title_part = track[last_dash + 3:]
    # Check if any artist exception is present
    for exc in artist_exceptions:
        if exc.lower() in artist_part.lower():
            return pd.Series([artist_part, title_part])
    # Split by first dash
    match = re.match(r'^(.*?)\s*-\s*(.*)$', track)
    if match:
        return pd.Series([match.group(1), match.group(2)])
    else:
        return pd.Series(['', track])

df_all[['artist_custom', 'title_custom']] = df_all['track'].apply(extract_artist_title)

# %%
# Checking again sample rows where the song title contains a dash (using the improved columns)
sample_with_dash_custom = df_all[df_all['title_custom'].str.contains("-", na=False)][['track', 'artist_custom', 'title_custom']].sample(50, random_state=42)
display(sample_with_dash_custom)
# Out:
#                                                      track  \
# 1108136  Kaczmarek Where Is Mr Barrie? - Kaczmarek - Wh...
# 712052   Chopin Sonata H-Moll Op. 58 Nobauer - Sonata H...
# 512716   Bach Koncert Skrzypcowy A-Moll Bwv 1041 Cz. I....
# 1373254  Clementi Symfonia Nr 1 C-Dur Cz Iii Menuet Moz...
# 300669      Disturbed - The Sound Of Silence - Cyril Remix
# 1515866       Daniel Pemberton - Spider-Woman (Gwen Stacy)
# 808948       Franz Schubert - Impromptu Ges-Dur Op.90 Nr 3
# 267689   Elsner Vesperae D-Dur Op 89 Zespol Muzyki Dawn...
# 1710785  Crosby, Stills & Nash - Suite- Judy Blue Eyes ...
# 482772   De Staat - De Staat - Get It Together (Vintici...
# 366691                  Kevin Kiner - Ahsoka - End Credits
# 1340626    Ossendowska Noc Reczeniedi & Dudzińska - 14-Noc
# 1585259  Sanah / Krzysztof Zalewski - Eviva L`arte (K. ...
# 496211   Mozart Koncert Fagotowy B-Dur Kv 191 Azzolini ...
# 1573102  Georg-Philipp Telemann - Koncert Na Trąbkę D-D...
# 512727   Jan Ap Kaczmarek - Magnezja Main Theme (Heroic...
# 1030434                   Stępniak-Wilk Basia - Obce Kraje
# 1391062  Britten Iii Kwartet Smyczkowy G-Dur Op. 94 Bel...
# 1492306                   10Cc - Art For Art's Sake - Live
# 753630                           E-Rotic - Help Me Dr.dick
# 288133   3-11 Porter - Surround Me With Your Love ( Men...
# 125837                Igor Herbut - Wkręceni - Nie Ufaj Mi
# 1026472  Tartini Koncert D-Dur Cz I Allegro Balsom Scot...
# 1179039  Monika Borzym Oraz T-Raperzy Znad Wisły - Kied...
# 1778021              Marc Shaiman - Addams Family - Finale
# 21233                          Enej - Symetryczno-Liryczna
# 833588                        One-T+Cool-T - The Magic Key
# 1202056  Lucy Rose - Merry Christmas Everyone - Live At...
# 250675           Jiri Antonin Benda - 5 Symfonia G-Dur (1)
# 1554740  Dvorak Kwintet Fortepianowy A-Dur Op. 81 Hamel...
# 1642065  Luciano Pavarotti & B.b. King - The Thrill Is ...
# 55454    Debussy Trois Chansons De Bilitis: Le Tombeau ...
# 625082   Edvard Grieg - Koncert Fortepianowy A-Moll Op....
# 676287   Rocławska - Musiałczyk Space Komendarek - Tyme...
# 1741323                       Lcd Soundsystem - X-Ray Eyes
# 183463   Naked Elephant - Naked Elephant - Raspberry Ki...
# 225437   Skip Marley - Exodus (Bob Marley: One Love - M...
# 1281261  Beethoven Twory Prometeusza Op. 43 Freiburger ...
# 769788                         Olivia Newton-John - Xanadu
# 1371330                             Squid - Cro-Magnon Man
# 430231                               C-Block - Keep Movin'
# 1822606                         Guy Barker - Pent-Up House
# 1232034         Lalo Schifrin - Mission Impossible - Theme
# 1755441  Campbell, Vibe Chemistry - I'm A Roller (La-Di...
# 152366   Franz Schubert - Kwintet Fortepianowy A-Dur Ps...
# 1754017     Disturbed - The Sound Of Silence - Cyril Remix
# 1151148  Lucy Rose - Merry Christmas Everyone - Live At...
# 554368                            The Connells - '74 - '75
# 1023237  Mozart Koncert Fortepianowy A-Dur K. 488 Cz. I...
# 1469289  Haydn Sonata Fortepianowa D-Dur Hob. Xvi:37 Ba...
#
#                                              artist_custom  \
# 1108136                      Kaczmarek Where Is Mr Barrie?
# 712052                                     Chopin Sonata H
# 512716                           Bach Koncert Skrzypcowy A
# 1373254                           Clementi Symfonia Nr 1 C
# 300669                                           Disturbed
# 1515866                                   Daniel Pemberton
# 808948                                      Franz Schubert
# 267689                                   Elsner Vesperae D
# 1710785                              Crosby, Stills & Nash
# 482772                                            De Staat
# 366691                                         Kevin Kiner
# 1340626             Ossendowska Noc Reczeniedi & Dudzińska
# 1585259                         Sanah / Krzysztof Zalewski
# 496211                           Mozart Koncert Fagotowy B
# 1573102                             Georg-Philipp Telemann
# 512727                                    Jan Ap Kaczmarek
# 1030434                                           Stępniak
# 1391062                    Britten Iii Kwartet Smyczkowy G
# 1492306                                               10Cc
# 753630                                                   E
# 288133                                                   3
# 125837                                         Igor Herbut
# 1026472                                  Tartini Koncert D
# 1179039                               Monika Borzym Oraz T
# 1778021                                       Marc Shaiman
# 21233                                                 Enej
# 833588                                                 One
# 1202056                                          Lucy Rose
# 250675                                  Jiri Antonin Benda
# 1554740                      Dvorak Kwintet Fortepianowy A
# 1642065                      Luciano Pavarotti & B.b. King
# 55454    Debussy Trois Chansons De Bilitis: Le Tombeau ...
# 625082                                        Edvard Grieg
# 676287                                           Rocławska
# 1741323                                    Lcd Soundsystem
# 183463                                      Naked Elephant
# 225437                                         Skip Marley
# 1281261  Beethoven Twory Prometeusza Op. 43 Freiburger ...
# 769788                                       Olivia Newton
# 1371330                                              Squid
# 430231                                                   C
# 1822606                                         Guy Barker
# 1232034                                      Lalo Schifrin
# 1755441                           Campbell, Vibe Chemistry
# 152366                                      Franz Schubert
# 1754017                                          Disturbed
# 1151148                                          Lucy Rose
# 554368                                        The Connells
# 1023237                      Mozart Koncert Fortepianowy A
# 1469289                        Haydn Sonata Fortepianowa D
#
#                                               title_custom
# 1108136                    Kaczmarek - Where Is Mr Barrie?
# 712052    Moll Op. 58 Nobauer - Sonata H-Moll Op. 58 Cz Iv
# 512716   Moll Bwv 1041 Cz. I. Mutter, Mutter's Virtuosi...
# 1373254  Dur Cz Iii Menuet Mozarteumorchester Salzburg ...
# 300669                  The Sound Of Silence - Cyril Remix
# 1515866                          Spider-Woman (Gwen Stacy)
# 808948                        Impromptu Ges-Dur Op.90 Nr 3
# 267689   Dur Op 89 Zespol Muzyki Dawnej Kapela Jasnogor...
# 1710785  Suite- Judy Blue Eyes (Live At Fillmore East, ...
# 482772     De Staat - Get It Together (Vinticious Version)
# 366691                                Ahsoka - End Credits
# 1340626                                             14-Noc
# 1585259                 Eviva L`arte (K. Przerwa-Tetmajer)
# 496211   Dur Kv 191 Azzolini Streichakademie Bozen - Ko...
# 1573102                        Koncert Na Trąbkę D-Dur (4)
# 512727   Magnezja Main Theme (Heroic Version) - Jan Ap ...
# 1030434                            Wilk Basia - Obce Kraje
# 1391062  Dur Op. 94 Belcea - Iii Kwartet Smyczkowy G-Du...
# 1492306                          Art For Art's Sake - Live
# 753630                             Rotic - Help Me Dr.dick
# 288133   11 Porter - Surround Me With Your Love ( Menta...
# 125837                              Wkręceni - Nie Ufaj Mi
# 1026472  Dur Cz I Allegro Balsom Scottish Ensemble Mort...
# 1179039              Raperzy Znad Wisły - Kiedy Pada Śnieg
# 1778021                             Addams Family - Finale
# 21233                                 Symetryczno-Liryczna
# 833588                            T+Cool-T - The Magic Key
# 1202056      Merry Christmas Everyone - Live At Maida Vale
# 250675                                5 Symfonia G-Dur (1)
# 1554740  Dur Op. 81 Hamelin T - 08 - Antonin Dvořak Pia...
# 1642065                          The Thrill Is Gone - Live
# 55454    07 - Debussy - Trois Chansons De Bilitis - 3. ...
# 625082               Koncert Fortepianowy A-Moll Op.16 (1)
# 676287   Musiałczyk Space Komendarek - Tymendorf - Spac...
# 1741323                                         X-Ray Eyes
# 183463      Naked Elephant - Raspberry Kiss (Original Mix)
# 225437   Exodus (Bob Marley: One Love - Music Inspired ...
# 1281261       Casado - Twory Prometeusza Op. 43 - Overture
# 769788                                       John - Xanadu
# 1371330                                     Cro-Magnon Man
# 430231                                 Block - Keep Movin'
# 1822606                                      Pent-Up House
# 1232034                         Mission Impossible - Theme
# 1755441                         I'm A Roller (La-Di-Da-Di)
# 152366               Kwintet Fortepianowy A-Dur Pstrąg (2)
# 1754017                 The Sound Of Silence - Cyril Remix
# 1151148      Merry Christmas Everyone - Live At Maida Vale
# 554368                                           '74 - '75
# 1023237  Dur K. 488 Cz. Iii. Allegro Assai Buniatishvil...
# 1469289  Dur Hob. Xvi:37 Batia - Sonata Fortepianowa D-...

# %%
# Find 100 most common song titles (title_custom) that contain a dash
top_titles_with_dash = (
    df_all[df_all['title_custom'].str.contains("-", na=False)]
    .groupby('title_custom')
    .size()
    .sort_values(ascending=False)
    .head(100)
)

output_path = "titles_with_dash.txt"
with open(output_path, "w", encoding="utf-8") as f:
    f.write("Most frequent song titles containing a dash:\n\n")
    for title in top_titles_with_dash.index:
        sample_row = df_all[df_all['title_custom'] == title].iloc[0]
        f.write(f"Title: {title}\n")
        f.write(f"Track: {sample_row['track']}\n")
        f.write(f"Extracted Artist: {sample_row['artist_custom']}\n")
        f.write('-'*60 + '\n')

print(f"Exported to {output_path}")
# Out:
# Exported to titles_with_dash.txt

# %%
# Display records where artist is empty or just spaces
blank_artist = df_all['artist_custom'].isna() | (df_all['artist_custom'].str.strip() == '')

blank_artist_records = df_all[blank_artist]
blank_artist_records
# Out:
# Empty DataFrame
# Columns: [date, time, station, track, artist, title, artist_custom, title_custom]
# Index: []

# %%
# Saving to file
blank_artist_records[['track', 'artist_custom', 'title_custom']].to_csv('blank_artist_records.csv', index=False)
# Out:
# Saved blank artist records to blank_artist_records.csv

# %%
# Removing rows where artist or title is blank (NaN or only whitespace)
df_all = df_all[
    df_all['artist_custom'].notna() & 
    (df_all['artist_custom'].str.strip() != '') &
    df_all['title_custom'].notna() & 
    (df_all['title_custom'].str.strip() != '')
]

# %%
# Drop old columns
df_all = df_all.drop(columns=['artist', 'title'])

# %%
# Rename 'artist_custom' and 'title_custom' to 'artist' and 'title'
df_all = df_all.rename(columns={'artist_custom': 'artist', 'title_custom': 'title'})

# %%
# Check data frame
df_all.head()
# Out:
#         date      time    station                           track     artist  \
# 0 2024-01-01  00:00:00  Antyradio             U2 - New Year's Day         U2
# 1 2024-01-01  00:05:00  Antyradio  Jet - Are You Gonna Be My Girl        Jet
# 2 2024-01-01  00:09:00  Antyradio         Green Day - Basket Case  Green Day
# 3 2024-01-01  00:12:00  Antyradio  Metallica - Whiskey In The Jar  Metallica
# 4 2024-01-01  00:17:00  Antyradio               T.love - Warszawa     T.love
#
#                       title
# 0            New Year's Day
# 1  Are You Gonna Be My Girl
# 2               Basket Case
# 3        Whiskey In The Jar
# 4                  Warszawa

# %% [markdown]
# ## 4. Data Analysis

# %%
# Number of unique radio stations
print(f"Number of unique radio stations: {df_all['station'].nunique():,}")
# Out:
# Number of unique radio stations: 13

# %%
# Alphabetical list of radio stations
sorted(df_all['station'].unique())
# Out:
# ['Antyradio',
#  'Chillizet',
#  'Czwórka',
#  'Dwójka',
#  'Eska',
#  'Jedynka',
#  'RMF Classic',
#  'RMF FM',
#  'RMF MAXXX',
#  'Trójka',
#  'VOX FM',
#  'ZET',
#  'Złote Przeboje']

# %%
df_all['station'].value_counts()
# Out:
# station
# Eska              198862
# RMF MAXXX         198006
# VOX FM            179647
# RMF Classic       169277
# Złote Przeboje    161937
# ZET               156065
# Antyradio         155279
# RMF FM            154736
# Chillizet         153501
# Czwórka           133584
# Trójka             78842
# Jedynka            60199
# Dwójka             35736
# Name: count, dtype: int64

# %%
## Data statistics
print(f"Number of records: {len(df_all):,}")
print(f"Number of unique artists: {df_all['artist'].nunique():,}")
print(f"Number of unique titles: {df_all['title'].nunique():,}")
print(f"Date range: {df_all['date'].min()} → {df_all['date'].max()}")
# Out:
# Number of records: 1,835,671
# Number of unique artists: 52,877
# Number of unique titles: 86,816
# Date range: 2024-01-01 00:00:00 → 2025-06-16 00:00:00

# %%
## Top 5 most popular artists
df_all['artist'].value_counts().head()
# Out:
# artist
# Dua Lipa           8770
# Sanah              8373
# Daria Zawiałow     7381
# Dawid Podsiadło    7255
# Oskar Cyms         6944
# Name: count, dtype: int64

# %%
## Top 5 most popular artists
df_all['track'].value_counts().head()
# Out:
# track
# Artemas - I Like The Way You Kiss Me      3344
# Dua Lipa - Houdini                        3032
# The Kolors - Un Ragazzo Una Ragazza       2847
# Chappell Roan - Good Luck, Babe!          2666
# Daria Zawiałow - Złamane Serce Jest Ok    2571
# Name: count, dtype: int64

# %%
## Top 5 most popular songs
df_all['title'].value_counts().head()

## The data looks different, e.g. Houdini - it's possible that several songs have the same title
# Out:
# title
# Houdini                       5512
# I Like The Way You Kiss Me    3344
# Róż                           3153
# I Like It                     2902
# Un Ragazzo Una Ragazza        2847
# Name: count, dtype: int64

# %%
# Top 10 (artist and title)
df_all.groupby(['artist', 'title']).size().sort_values(ascending=False).head(10)

# OK :) The title "Houdini" refers to two different songs (Dua Lipa, Eminem)
# Out:
# artist             title
# Artemas            I Like The Way You Kiss Me    3344
# Dua Lipa           Houdini                       3032
# The Kolors         Un Ragazzo Una Ragazza        2847
# Chappell Roan      Good Luck, Babe!              2666
# Daria Zawiałow     Złamane Serce Jest Ok         2571
# Sylwia Grzeszczak  Och I Ach                     2532
# Kaeyra             Sour                          2524
# Eminem             Houdini                       2462
# Hozier             Too Sweet                     2352
# The Kolors         Italodisco                    2286
# dtype: int64

# %%
top20_tracks = df_all['track'].value_counts().head(20)
print(top20_tracks)
# Out:
# track
# Artemas - I Like The Way You Kiss Me        3344
# Dua Lipa - Houdini                          3032
# The Kolors - Un Ragazzo Una Ragazza         2847
# Chappell Roan - Good Luck, Babe!            2666
# Daria Zawiałow - Złamane Serce Jest Ok      2571
# Sylwia Grzeszczak - Och I Ach               2532
# Kaeyra - Sour                               2524
# Eminem - Houdini                            2462
# Hozier - Too Sweet                          2352
# The Kolors - Italodisco                     2286
# Dua Lipa - Training Season                  2205
# Mark Ambor - Belong Together                2181
# Damiano David - Born With A Broken Heart    2147
# Sabrina Carpenter - Espresso                2141
# Teddy Swims - Bad Dreams                    2033
# Lady Gaga - Abracadabra                     2017
# Wiktor Dyduła - Tam Słońce Gdzie My         2005
# Dawid Podsiadło - Pięknie Płyniesz          1986
# Sanah - Było, Minęło                        1952
# Cyril - Stumblin" In                        1919
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Visualizations

# %%
top20 = (
    df_all.groupby(['artist', 'title'])
    .size()
    .sort_values(ascending=False)
    .head(10)
    .reset_index(name='Number of plays')
)

import plotly.express as px
px.bar(
    top20,
    x='Number of plays',
    y=top20['artist'] + ' - ' + top20['title'] + ' ',
    orientation='h',
    title='Top 10 most played songs',
    height=800
)

# %%
# Top 20 most frequently played tracks

# Create the output folder
output_folder = "report_outputs"
os.makedirs(output_folder, exist_ok=True)

# Prepare data for top tracks
top_tracks = (
    df_all.groupby(['artist', 'title'])
    .size()
    .sort_values(ascending=False)
    .head(20)
    .reset_index(name='Play count')
)

# Bar plot
fig = px.bar(
    top_tracks,
    x='Play count',
    y=top_tracks['artist'] + ' - ' + top_tracks['title'],
    orientation='h',
    title='Top 20 most frequently played tracks',
    height=800
)

# Save plot as HTML file
fig.write_html(os.path.join(output_folder, "top20_tracks.html"))

# %%
# Top 20 most frequently played artists

# Top 20 artists
top_artists_series = df_all['artist'].value_counts().head(20)
top_artists = top_artists_series.reset_index()
top_artists.columns = ['artist', 'Play count']

# Plot
fig = px.bar(
    top_artists,
    x='Play count',
    y='artist',
    orientation='h',
    title='Top 20 most frequently played artists',
    height=700
)

# Save plot as HTML file
fig.write_html(os.path.join(output_folder, "top20_artists.html"))

# %%
# Monthly plays for top 5 tracks per station - scatter plot

# Output folders
main_folder = "report_outputs"
subfolder = os.path.join(main_folder, "monthly_per_station")
os.makedirs(subfolder, exist_ok=True)

# Add a month column
df_all['month'] = (
    pd.to_datetime(df_all['date'])
    .dt.to_period('M')
    .dt.to_timestamp()
)

# Find the top 5 tracks (artist + title) for each station
top5 = (
    df_all
    .groupby(['station', 'artist', 'title'])
    .size()
    .reset_index(name='count')
    .sort_values(['station', 'count'], ascending=[True, False])
    .groupby('station')
    .head(5)
)

# Filter the original data to only top 5 tracks per station
df_top5 = df_all.merge(
    top5[['station', 'artist', 'title']],
    on=['station', 'artist', 'title'],
    how='inner'
)

# Generate separate HTML reports for each radio station
for station, grp in df_top5.groupby('station'):
    # Prepare monthly data for the top 5 tracks
    monthly = (
        grp
        .groupby(['month', 'artist', 'title'])
        .size()
        .reset_index(name='plays')
    )
    monthly['track_label'] = monthly['artist'] + ' - ' + monthly['title']

    # Create a scatter plot for monthly plays
    fig = px.scatter(
        monthly,
        x='month',
        y='track_label',
        size='plays',
        title=f'Monthly plays for top 5 tracks - {station}',
        height=600
    )
    fig.update_yaxes(title_text='')

    # Save to HTML file
    filename = f"top5_monthly_{station.replace(' ', '_')}.html"
    fig.write_html(os.path.join(subfolder, filename))

# %%
# Average number of plays per station and hour

# Extract the hour from the time column
df_all['hour'] = pd.to_datetime(df_all['time'], format='%H:%M:%S', errors='coerce').dt.hour

# Count plays per station, hour, and date
plays_per_day = (
    df_all
    .groupby(['station', 'hour', 'date'])
    .size()
    .reset_index(name='plays')
)

# Calculate the average number of plays per station and hour
avg_plays = (
    plays_per_day
    .groupby(['station', 'hour'])['plays']
    .mean()
    .reset_index(name='avg_plays')
)

avg_plays
# Out:
#             station  hour  avg_plays
# 0         Antyradio     0  15.028384
# 1         Antyradio     1  14.227571
# 2         Antyradio     2  15.480151
# 3         Antyradio     3  15.859023
# 4         Antyradio     4  15.854991
# ..              ...   ...        ...
# 307  Złote Przeboje    19  12.118421
# 308  Złote Przeboje    20   9.654135
# 309  Złote Przeboje    21  10.500000
# 310  Złote Przeboje    22  14.939509
# 311  Złote Przeboje    23  14.733962
#
# [312 rows x 3 columns]

# %%
plays_per_day
# Out:
#                station  hour       date  plays
# 0            Antyradio     0 2024-01-01     12
# 1            Antyradio     0 2024-01-02     12
# 2            Antyradio     0 2024-01-03     12
# 3            Antyradio     0 2024-01-04     12
# 4            Antyradio     0 2024-01-05     13
# ...                ...   ...        ...    ...
# 154594  Złote Przeboje    23 2025-06-12     15
# 154595  Złote Przeboje    23 2025-06-13     16
# 154596  Złote Przeboje    23 2025-06-14     16
# 154597  Złote Przeboje    23 2025-06-15     15
# 154598  Złote Przeboje    23 2025-06-16     15
#
# [154599 rows x 4 columns]

# %%
plays_per_day_sorted = plays_per_day.sort_values(by='plays', ascending=False)
plays_per_day_sorted
# Out:
#                station  hour       date  plays
# 46868             Eska     2 2024-10-27     38
# 118192          VOX FM     2 2024-10-27     38
# 1214         Antyradio     2 2024-10-27     33
# 130528             ZET     2 2024-10-27     33
# 143188  Złote Przeboje     2 2024-10-27     32
# ...                ...   ...        ...    ...
# 31655          Czwórka    13 2024-08-01      1
# 31691          Czwórka    13 2024-09-06      1
# 31773          Czwórka    13 2024-11-29      1
# 31580          Czwórka    13 2024-05-15      1
# 31592          Czwórka    13 2024-05-28      1
#
# [154599 rows x 4 columns]

# %%
avg_plays_sorted = avg_plays.sort_values(by='avg_plays', ascending=False)
avg_plays_sorted
# Out:
#        station  hour  avg_plays
# 101       Eska     5  22.552830
# 197  RMF MAXXX     5  20.778612
# 119       Eska    23  20.537736
# 100       Eska     4  19.983051
# 118       Eska    22  19.664151
# ..         ...   ...        ...
# 85      Dwójka    13   2.384880
# 91      Dwójka    19   2.038328
# 124    Jedynka     4   1.640000
# 142    Jedynka    22   1.630695
# 123    Jedynka     3   1.425532
#
# [312 rows x 3 columns]

# %%
no_music = avg_plays[avg_plays['avg_plays'] <= 5]
no_music.to_html("report_outputs/hours_no_music_avg.html", index=False)
no_music
# Out:
#      station  hour  avg_plays
# 72    Dwójka     0   4.755656
# 73    Dwójka     1   4.079295
# 74    Dwójka     2   2.667883
# 75    Dwójka     3   3.544503
# 76    Dwójka     4   2.733564
# 77    Dwójka     5   4.455385
# 83    Dwójka    11   4.572383
# 84    Dwójka    12   3.746556
# 85    Dwójka    13   2.384880
# 86    Dwójka    14   3.539359
# 87    Dwójka    15   4.193220
# 88    Dwójka    16   4.458738
# 89    Dwójka    17   3.685185
# 90    Dwójka    18   4.768061
# 91    Dwójka    19   2.038328
# 92    Dwójka    20   2.575221
# 93    Dwójka    21   3.574359
# 94    Dwójka    22   2.546358
# 95    Dwójka    23   4.639269
# 123  Jedynka     3   1.425532
# 124  Jedynka     4   1.640000
# 132  Jedynka    12   3.795455
# 133  Jedynka    13   4.210216
# 137  Jedynka    17   5.000000
# 139  Jedynka    19   3.063655
# 141  Jedynka    21   4.590336
# 142  Jedynka    22   1.630695
# 239   Trójka    23   4.455446
# 267      ZET     3   4.368620

# %%
# For each station, select the 5 hours with the highest average number of plays
most_musical = (
    avg_plays
    .sort_values(['station', 'avg_plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
)

most_musical
# Out:
#             station  hour  avg_plays
# 5         Antyradio     5  16.157895
# 3         Antyradio     3  15.859023
# 4         Antyradio     4  15.854991
# 2         Antyradio     2  15.480151
# 0         Antyradio     0  15.028384
# ..              ...   ...        ...
# 292  Złote Przeboje     4  16.045113
# 291  Złote Przeboje     3  15.919325
# 290  Złote Przeboje     2  15.706215
# 293  Złote Przeboje     5  15.341463
# 288  Złote Przeboje     0  15.145009
#
# [65 rows x 3 columns]

# %%
# Save as HTML table
most_musical.to_html("report_outputs/hours_most_musical_avg.html", index=False)

# %%
# Average number of plays per Station and Hour

# Pivot: station × hour with avg_plays as values
pivot_avg = avg_plays.pivot(index='hour', columns='station', values='avg_plays')

# Plot heatmap
fig = px.imshow(
    pivot_avg.T,
    x=pivot_avg.index,
    y=pivot_avg.columns,
    labels={'x': 'hour', 'y': 'station', 'color': 'average number of plays'},
    title='Average number of plays per Station and Hour',
    aspect='auto'
)

# Save to HTML
fig.write_html(os.path.join(output_folder, "heatmap_avg_plays_per_station.html"))

# %%
# # Average number of plays per Station and Hour - differnet colour
# # Pivot: station × hour with avg_plays as values
pivot_avg = avg_plays.pivot(index='hour', columns='station', values='avg_plays')

# A single-color scale (blues)
import plotly.express as px
fig = px.imshow(
    pivot_avg.T,
    x=pivot_avg.index,
    y=pivot_avg.columns,
    labels={'x': 'hour', 'y': 'station', 'color': 'average number of plays'},
    title='# Average number of plays per Station and Hour',
    aspect='auto',
    color_continuous_scale='Blues'
)

# Save to HTML
fig.write_html(os.path.join(output_folder, "heatmap_avg_plays_per_station_color.html"))

# %%
# Song premiere analysis

# 1. Prepare a datetime column by combining date and time
df_all['datetime'] = pd.to_datetime(
    df_all['date'].dt.strftime('%Y-%m-%d') + ' ' + df_all['time'].astype(str),
    format='%Y-%m-%d %H:%M:%S'
)

# 2. Find the first play (premiere) of each song (by artist and title)
first_plays = (
    df_all
    .sort_values('datetime')
    .groupby(['artist', 'title'], as_index=False)
    .first()[['artist', 'title', 'station', 'datetime']]
)

# 3. Filter premieres that happened in 2025
premieres_2025 = first_plays[first_plays['datetime'].dt.year == 2025]

# 4. Count the number of premieres per station
premieres_per_station = (
    premieres_2025['station']
    .value_counts()
    .reset_index(name='number_of_premieres')
    .rename(columns={'index': 'station'})
)

premieres_per_station

# %%
# Display premieres only for a specific station, e.g. Eska
eska_premieres = premieres_2025[premieres_2025['station'] == 'Eska']

# Print a table with artist, title, and datetime
print(eska_premieres[['artist', 'title', 'datetime']].to_string(index=False))
# Out:
#                                                                                       artist                               title            datetime
#                                                               Adam Levine & Gym Class Heroes                       Stereo Hearts 2025-06-16 03:09:00
#                                                                               Adma & Filipek                          Easy Peasy 2025-03-17 05:27:00
#                                                                    Akon & Kardinal Offishall                           Dangerous 2025-06-12 22:41:00
#                                                                              Alan Walker & K                        391 - Ignite 2025-06-16 02:59:00
#                                                                    Alan Walker & Sofia Reyes                       Guaro Con Ron 2025-06-12 14:28:00
#                                                                         Alan Walker & Sorana                   Mind Of A Warrior 2025-04-27 13:31:00
#                                                                                   Alessandra                            Non Stop 2025-04-25 18:20:00
#                                                                          Alesso & Becky Hill                           Surrender 2025-04-04 17:31:00
#                                                                              Alexander Rybak                   Fairytale (Remix) 2025-05-04 18:22:00
#                                                         Alle Farben & Anna Naklab & Younotus                           Supergirl 2025-06-14 09:03:00
#                                                                         Alok & Kylie Minogue  Last Night I Dreamt I Fell In Love 2025-02-14 16:32:00
#                                                                                 Alvaro Soler                           Con Calma 2025-03-07 09:35:00
#                                                                                    Anastacia                      Sick And Tired 2025-06-15 18:44:00
#                                                                    Anastazja Maciąg & Questy                                  21 2025-06-15 05:03:00
#                                                                       Anyma & Ellie Goulding                          Hypnotized 2025-01-10 08:47:00
#                                                                                Aria Martelle                       Rollercoaster 2025-06-10 05:00:00
#                                                                                Ariana Grande                       Twilight Zone 2025-03-28 12:36:00
#                                                 Armin Van Buuren & Alok & Norma Jean Martine                            Euphoria 2025-01-03 17:56:00
#                                                                                  Asaf Avidan            One Day / Reckoning Song 2025-04-20 18:41:00
#                                                                                      Ava Max                        Lovin Myself 2025-05-30 17:56:00
#                                                                                       Avicii                       Forever Yours 2025-02-14 08:48:00
#                                                                           Avicii & Elle King                     Let's Ride Away 2025-05-16 14:36:00
#                                                                                  Bambi & Oki                 To Nie Ma Znaczenia 2025-02-14 19:24:00
#                                                                  Bastille & Lost Frequencies                           Head Down 2025-06-13 07:55:00
#                                                                                 Benson Boone                    Mystical Magical 2025-04-25 08:09:00
#                                                                                 Benson Boone     Sorry I'm Here For Someone Else 2025-02-28 11:36:00
#                                              Blacha & Bedoes & White 2115 & 2115 & Kuqe 2115                             Ketchup 2025-06-13 02:52:00
#                                                                                       Bletka                         Bucket List 2025-05-02 19:09:00
#                                                                            Bruno Mars & Rosé                                Apt. 2025-06-12 17:17:00
#                                                                                          Bsk                         Przez Ekran 2025-05-05 23:11:00
#                                                                         Bsk & Francis & Waro                   Lepiej Bez Ciebie 2025-03-03 23:23:00
#                                                                                Calvin Harris                 Smoke The Pain Away 2025-03-14 08:19:00
#                                                           Calvin Harris & Clementine Douglas                           Blessings 2025-05-09 17:55:00
#                                                                              Carla Fernandes                          Co, Jeśli? 2025-03-23 17:31:00
#                                                            Cheat Codes & Edward Maya & Enisa                      Be Your Friend 2025-05-30 18:10:00
#                                                                           Cherish & Yung Joc                               Killa 2025-05-25 18:44:00
#                                                                                      Chermee                          Przy Tobie 2025-05-07 23:55:00
#                                                                                  Cheryl Cole                        Call My Name 2025-03-09 18:44:00
#                                                                                       Chivas                            Hellstar 2025-01-14 00:07:00
#                                                                            Chrystal & Notion             The Days (Notion Remix) 2025-01-24 18:10:00
#                                                                Clean Bandit & Tiesto & Leony                  Tell Me Where U Go 2025-04-25 19:38:00
#                                    Cleo & Viki Gabor & Wac Toja & Golec Uorkiestra & Donatan                   Czym Chata Bogata 2025-01-29 20:16:00
#                                                                          Craig David & Sting                         Rise & Fall 2025-03-30 18:42:00
#                                                                          Cyril & James Blunt                   Tears Dry Tonight 2025-04-25 11:36:00
#                                                                                Damiano David                         Next Summer 2025-02-28 08:49:00
#                                                                                Damiano David                         Zombie Lady 2025-05-16 09:33:00
#                                                           Daniel Godson & Def Jam World Tour                              Zawsze 2025-03-08 05:03:00
#                                                              Daria Zawiałow & Taco Hemingway                           Mix Sałat 2025-06-14 03:22:00
#                                                                      David Guetta & Flo Rida                Club Can't Handle Me 2025-06-12 15:49:00
#                                                                           David Guetta & Sia                    Beautiful People 2025-03-09 09:33:00
#                                                                    Dawid Kwiatkowski & Kayah                        Proszę Tańcz 2025-01-14 20:24:00
#                                                             Dawid Podsiadło & Kaśka Sochacka                            Samoloty 2025-05-23 01:05:00
#                                                                      Dawid Podsiadło & Sanah                   Ostatnia Nadzieja 2025-06-12 12:16:00
#                                                                          Dj Fresh & Rita Ora                       Hot Right Now 2025-04-20 19:38:00
#                                                          Dj Khaled & Rihanna & Bryson Tiller                       Wild Thoughts 2025-04-06 19:37:00
#                                                                                      Doechii                             Anxiety 2025-03-04 19:14:00
#                                                                       Doja Cat & Don Toliver                        Lose My Mind 2025-06-12 12:13:00
#                                                                                Dominik Dudek                      Hold The Light 2025-01-10 10:38:00
#                                                                       Don Toliver & Doja Cat                        Lose My Mind 2025-05-02 18:41:00
#                                                                                Doniu & Liber                              Skarby 2025-06-14 02:48:00
#                                                               Drenchill & Conki & Albert Rcb                        I Don't Know 2025-03-28 10:35:00
#                                                                             Dvbbs & Borgeous                             Tsunami 2025-01-26 18:44:00
#                                                                                   Ed Sheeran                              Azizam 2025-04-04 07:09:00
#                                                                                   Ed Sheeran                            Sapphire 2025-06-06 09:34:00
#                                                                                        Ekipa                              Labubu 2025-06-14 18:14:00
#                                                                                        Elena                Działasz Na Mnie Jak 2025-03-14 05:27:00
#                                                               Ellie Goulding & Calvin Harris                    I Need Your Love 2025-06-14 14:32:00
#                                                         Ellie Goulding & Marshmello & Avaion                        Save My Love 2025-06-13 18:51:00
#                                                                                       Eminem                        Just Lose It 2025-03-30 17:55:00
#                                                                 Enrique Iglesias & Nicky Jam                           El Perdon 2025-06-13 13:56:00
#                                                        Enrique Iglesias & Pitbull & Iamchino                           Tamo Bien 2025-03-07 19:26:00
#                                                                    Eurythmics & Steve Angelo                        Sweet Dreams 2025-04-23 17:48:00
#                                                                                      Example         Changed The Way You Kiss Me 2025-01-05 19:11:00
#                                                                                       Fabson                         Mieć Więcej 2025-02-03 23:04:00
#                                                                        Fast Boy & Clockclock                          Born Again 2025-03-28 14:37:00
#                                                                                  Fatboy Slim                   Rockafeller Skank 2025-02-23 19:27:00
#                                                                                         Fdvm                     A Girl Like You 2025-04-04 18:38:00
#                                                                                  Felix Jaehn                               Pride 2025-05-30 08:09:00
#                                                                                Filipek & Nel                       Nie Ma Chemii 2025-03-22 15:32:00
#                                                                    Filipek & Nel & Clearmind                            Na Serio 2025-02-28 18:40:00
#                                                                     Filipek & Nel & Sir Mich                     Niech Się Kręci 2025-04-18 18:20:00
#                                         Flo Rida & Heeseung & Jake Of Enhypen & Paul Russell                         Confessions 2025-01-10 18:42:00
#                                                                         Flo Rida & Taio Cruz                            Hangover 2025-06-12 21:21:00
#                                                                          Francis & Kuqe 2115                        Taki Mały Ja 2025-06-14 10:25:00
#                                                                                        Gabor                        Love Forever 2025-03-23 23:47:00
#                                                                          Gabry Ponte & Train                       Brokenhearted 2025-05-16 17:34:00
#                                                                 Gabry Ponte & Village People                 Frequency (Go West) 2025-04-18 19:24:00
#                                                                                 Gibbs & Opał                            Pod Prąd 2025-03-07 12:13:00
#                                                                    Golec Uorkiestra & Bedoes                             Janosik 2025-06-14 02:57:00
#                                                  Gombao 33 & Mata & Wyguś & Tadeo & Szczepan             Nienawidzę Być W Klubie 2025-02-14 19:06:00
#                                                                      Goodwill & Hook N Sling                     Take You Higher 2025-01-05 17:54:00
#                                                                                       Gromee                             Goodbye 2025-03-07 19:09:00
#                                                                                 Gwen Stefani                What You Waiting For 2025-03-02 17:52:00
#                                                                            H Two O & Platnum                  What's It Gonna Be 2025-05-25 18:21:00
#                                                                               Hanafi & Adash                            Urodziny 2025-05-05 23:08:00
#                                                                                 Iga Jaworska                               Tadam 2025-04-11 05:26:00
#                                                                          Ikarus Feel & Tymek                      Antydepresanty 2025-02-01 05:28:00
#                                                                                      Imanbek                              Limits 2025-06-13 19:25:00
#                                                                                     Infernal                        Self Control 2025-05-18 18:57:00
#                                                                                 Inna & R3Hab                     I'll Be Waiting 2025-05-16 18:10:00
#                                                                                         Jade           Fufn (Forget You For Now) 2025-03-21 18:11:00
#                                                                                   James Hype                    Don't Wake Me Up 2025-03-21 19:08:00
#                                                                                Jan-Rapowanie                 Groteska [Explicit] 2025-01-20 23:36:00
#                                                                       Jan-Rapowanie & Szpaku                           W Dresach 2025-03-03 23:28:00
#                                                                                 Jason Derulo                              Wiggle 2025-02-02 19:39:00
#                                                                       Jaxomy & Conor Maynard                       She's So High 2025-02-14 10:38:00
#                                                                              Jay-Z & Beyonce                       Crazy In Love 2025-06-15 17:54:00
#                                                                            Jennie & Dua Lipa                          Handlebars 2025-03-07 18:23:00
#                                                                                    Joe Stone                        Donna Summer 2025-05-09 19:25:00
#                                                                                        Jubël                             Walkman 2025-05-23 13:34:00
#                                                                               Julia Michaels                              Issues 2025-04-06 17:54:00
#                                                                                  Julia Rocka            F*Boy (Chciałbyś Więcej) 2025-04-25 13:35:00
#                                                                                  Julia Rocka                             F*Ckboy 2025-04-04 19:06:00
#                                                                               Julia Wieniawa                             Od Nowa 2025-04-25 10:37:00
#                                                                                Justin Bieber                                Baby 2025-06-01 19:26:00
#                                                                Justin Bieber & The Kid Laroi                                Stay 2025-06-14 10:11:00
#                                                                                 Kabe & Opiat                             Quattro 2025-03-24 23:54:00
#                                                                    Kacperczyk & Kinny Zimmer                   Nieprzespane Noce 2025-05-23 18:52:00
#                                                                                       Kamrad                             Be Mine 2025-05-16 15:32:00
#                                                                       Kasia Kowalska & Sanah                 Kiedy Umrę Kochanie 2025-06-12 13:18:00
#                                                                              Kazik & Yugoton                            Malcziki 2025-06-14 00:33:00
#                                                                                 Kim Cesarion                           Undressed 2025-04-24 15:24:00
#                                                           Kinny Zimmer & White 2115 & Kaptur            Nie Ma Cb (Przy Mnie Tu) 2025-03-26 19:10:00
#                                                                                         Kizo                           Kierownik 2025-02-24 23:26:00
#                                                                      Kleerpu/Titiyo & Titiyo               Longing For Lullabies 2025-05-25 19:12:00
#                                                                          Kleks & Marta Bijan                           Na Zawsze 2025-03-08 05:00:00
#                                                                                  Kronkel Dom                    Champions League 2025-05-05 23:36:00
#                                                                                  Kuba I Kuba                                Dość 2025-05-17 09:32:00
#                                                                                Kuban & Favst                      Sam Na Świecie 2025-03-03 23:16:00
#                                                                        Kuban & Mrozu & Favst                Zanim Spadnie Deszcz 2025-01-24 12:36:00
#                                                                                Kuban & Zalia                               Kyoto 2025-05-02 19:26:00
#                                                                           Kubańczyk & Tribbs       Ostatni Raz Zatańczysz Ze Mną 2025-06-14 04:52:00
#                                                                         Kubańczyk & Zeamsone                        Social Media 2025-03-24 23:57:00
#                                                               Kubi Producent & Fukaj & Bambi                     Woda Księżycowa 2025-06-13 01:52:00
#                                                                   Kubi Producent & Kuqe 2115           Wszystkie Noce Są Samotne 2025-06-13 22:48:00
#                                                                 Kungs & Purple Disco Machine                        Substitution 2025-06-13 07:16:00
#                                                                      Kuqe 2115 & Kuban & Emi                           Baletnica 2025-03-24 23:21:00
#                                                                           Kygo & Onerepublic                    Chasing Paradise 2025-01-24 17:31:00
#                                                                        Kękę & Adz & Dj Vazee                       Do Góry Głowa 2025-05-26 23:19:00
#                                                                                    Lady Gaga                      Garden Of Eden 2025-03-07 17:58:00
#                                                                           Lavinia & Ely Oaks                         My Birthday 2025-01-31 17:32:00
#                                                                                  Le Sserafim                           Come Over 2025-03-14 18:40:00
#                                                                        Lenny Kravitz & Quavo                                 Fly 2025-06-12 17:50:00
#                                                                                 Liber & Mezo                              Aniele 2025-06-13 04:34:00
#                                                                     Liber & Natalia Szroeder                  Wszystkiego Na Raz 2025-06-13 00:40:00
#                                                                       Lisa & Doja Cat & Raye                          Born Again 2025-02-13 17:34:00
#                                                                                        Lmfao                  Sexy And I Know It 2025-01-05 19:23:00
#                                                                                          Loi                           Get Lucky 2025-06-13 11:35:00
#                                                 Lost Frequencies & X Ambassadors & Ella Duhe                         Back To You 2025-06-14 22:53:00
#                                                          Lucas Estrada & Younotus & Sam Gray                       Love Me Again 2025-05-09 15:27:00
#                                                                             Ludacris & Usher                                Yeah 2025-06-13 11:08:00
#                                                                                 Lukas Graham                         You You You 2025-04-18 17:33:00
#                                                           Lukasz Zagrobelny & Ewelina Flinta            Nie Klam Ze Kochasz Mnie 2025-06-14 02:21:00
#                                                                                        Lum!X                            Illusion 2025-03-28 16:30:00
#                                                                                         Luna                        Wszystko Gra 2025-04-13 12:34:00
#                                                                                 Maciej Skiba                 Czy O Mnie Myślisz? 2025-05-18 17:33:00
#                                                                                 Magda Bereda                          Ani Trochę 2025-06-12 20:14:00
#                                                                      Magiera & Kajetan Wolas                                Mama 2025-06-14 05:10:00
#                                                                              Maja Krzyżewska                        O Tobie Wers 2025-03-28 05:27:00
#                                                                                Malik Montana                          Sentymenty 2025-03-20 20:11:00
#                                                                       Malik Montana & Blanka                              Wracam 2025-06-13 15:31:00
#                                                                       Malik Montana & Żabson                            Do Tańca 2025-01-23 19:15:00
#                                                                               Mans Zelmerlow                          Revolution 2025-02-21 14:35:00
#                                                                            Marcus & Martinus                      Endless Summer 2025-05-09 11:36:00
#                                                                Margaret & Zalia & Sara James                           Co Za Noc 2025-04-11 11:35:00
#                                                                                   Mark Ambor                           Who Knows 2025-05-09 13:34:00
#                                                                              Maroon 5 & Lisa                           Priceless 2025-05-02 17:55:00
#                                                         Marshmello & Ellie Goulding & Avaion                        Save My Love 2025-06-06 13:34:00
#                                                                  Marshmello & Jonas Brothers                         Slow Motion 2025-01-17 10:34:00
#                                                  Mata & Wyguś & Szczepan & Gombao 33 & Tadeo             Nienawidzę Być W Klubie 2025-06-13 00:06:00
#                                                                               Mery Biernacka                         Niech Mówią 2025-05-09 05:26:00
#                                                                                         Meya                       Złamane Serce 2025-01-31 19:47:00
#                                                                        Michael Patrick Kelly                             The One 2025-04-25 17:33:00
#                                                                              Michael Schulte                           Afterlife 2025-04-04 10:37:00
#                                                                             Michał Szczygieł                            Ostatnio 2025-04-18 15:33:00
#                                                                             Michał Szczygieł                              Wariat 2025-03-14 19:09:00
#                                                                     Michał Szczygieł & Sobel                         Daj Mi Znać 2025-06-13 02:35:00
#                                                                                      Mikolas                               Samba 2025-05-09 18:51:00
#                                                                                  Miley Cyrus                    End Of The World 2025-04-04 08:09:00
#                                                                                Miriana Conte                                Kant 2025-02-21 18:41:00
#                                                                     Miszel & Pezet & Premixm              Zrobiłem To Po Swojemu 2025-03-31 23:12:00
#                                                                  Mo & Dj Snake & Major Lazer                             Lean On 2025-06-16 03:18:00
#                                                                                      Molella                             Goodbye 2025-03-14 18:22:00
#                                                                                        Motyl                             Zapalki 2025-03-23 05:00:00
#                                                                                        Motyl                              Zobacz 2025-02-15 20:18:00
#                                                                        Mrozu & Favst & Kuban                Zanim Spadnie Deszcz 2025-06-12 16:30:00
#                                                                                  Myles Smith                                Gold 2025-05-23 09:36:00
#                                                                 Męskie Granie Orkiestra 2025                  To Bardzo Ziemskie 2025-06-05 12:02:00
# Męskie Granie Orkiestra 2025 & Ralph Kamiński & Igor Herbut & Natalia Przybysz & Błażej Król                  To Bardzo Ziemskie 2025-06-05 20:13:00
#                                                                   Ne-Yo & Pitbull & Afrojack                  Give Me Everything 2025-06-13 23:32:00
#                                                                                        Nelly                        Just A Dream 2025-04-13 19:27:00
#                                                                    Nelly Furtado & Timbaland                       Give It To Me 2025-06-13 14:13:00
#                                                                                Nessa Barrett                            P*Rnstar 2025-02-03 13:55:00
#                                                                                Nessa Barrett                            Pornstar 2025-01-31 18:12:00
#                                                                     Nicki Minaj & Kim Petras                               Alone 2025-06-15 09:50:00
#                                                                             Nieprofesjonalny       To Ja (Ten Z Ostatniej Ławki) 2025-05-07 23:44:00
#                                                                     Nikoś & Szaran & Jonatan                           Backstage 2025-05-26 23:55:00
#                                                                                     Ofenbach                   Need You The Most 2025-03-21 17:33:00
#                                                                        Oki & Francis & Bambi                          1Day In La 2025-06-13 09:33:00
#                                                                                  Oki & Sobel                          Szary Blok 2025-02-10 23:34:00
#                                                                         Oki & Taco Hemingway                             Day One 2025-04-15 00:00:00
#                                                                                  Onerepublic                          Invincible 2025-04-18 11:36:00
#                                                                                 Opał & Gibbs                               Drive 2025-06-14 10:47:00
#                                                                                 Opał & Gibbs           Nocne Jazdy (Favst Remix) 2025-06-02 23:35:00
#                                 Otsochodzi & Reni Jusis & Oki & Young Multi & Lohleq & Kusha                   Kiedyś Cię Znajdę 2025-02-17 23:29:00
#                                                           Otsochodzi & Young Igi & Oio & Oki                         Przypadkiem 2025-06-14 01:44:00
#                                                                Pascal Letoublon & Lucky Rose                     Lost In The Sun 2025-03-28 18:19:00
#                                                  Pawbeats & Katarzyna Grzesiek & Quebonafide                             Euforia 2025-06-14 04:08:00
#                                                                                 Pezet & Auer                        Dom Nad Wodą 2025-01-06 23:14:00
#                                                                                      Pik Pik                              4 Life 2025-04-14 23:30:00
#                                                                        Pitbull & Chris Brown                  International Love 2025-04-24 15:31:00
#                                                                   Pitbull & Enrique Iglesias                           I Like It 2025-06-15 11:35:00
#                                                        Pitbull & Enrique Iglesias & Iamchino                           Tamo Bien 2025-06-12 12:05:00
#                                                    Pitbull & Jennifer Lopez & Claudia Leitte                We Are One (Ole Ola) 2025-02-02 19:27:00
#                                                                          Pitbull & John Ryan                            Fireball 2025-03-23 18:44:00
#                                                                      Po Prostu Damian & Tabb                         Wracamy Tam 2025-03-22 05:21:00
#                                                                           Przyłu & Kuba Hejz                    Cały W Kawałkach 2025-05-26 23:41:00
#                                                                                Przyłu & Leeo                      Lodowate Serce 2025-03-03 23:08:00
#                                                                         Psr & Paluch & Gibbs                              Indica 2025-01-13 23:54:00
#                                                           Qry & Bartek Kubicki & Przemek.pro                          Przestrzeń 2025-01-18 21:13:00
#                                                       R3Hab & Michael Patrick Kelly & Shaggy                           Rebellion 2025-02-14 14:38:00
#                                                                      R3Hab & Michael Schulte                           Waterfall 2025-06-12 22:21:00
#                                                                     Ray Dalton & Felix Jaehn                        Call It Love 2025-06-13 08:24:00
#                                                                      Rihanna & Calvin Harris           This Is What You Came For 2025-06-12 12:33:00
#                                                        Rihanna & Kanye West & Paul Mccartney                     Fourfiveseconds 2025-02-09 17:55:00
#                                                                       Rita Ora & Iggy Azalea                         Black Widow 2025-06-14 09:23:00
#                                                                              Robbie Williams                            Trippin' 2025-03-23 18:57:00
#                                                 Robert Miles & Ella Henderson & Switch Disco                               React 2025-06-14 23:54:00
#                                                                   Robin Schulz & Oliver Tree                            Miss You 2025-06-13 11:14:00
#                                                                                         Rose                  Toxic Till The End 2025-01-03 18:10:00
#                                                                                         Rosé                               Messy 2025-05-09 18:09:00
#                                                                                 Roxie Węgiel                            Bez Słów 2025-05-07 20:25:00
#                                                                            Sabrina Carpenter                          Busy Woman 2025-02-14 12:36:00
#                                                                            Sabrina Carpenter                            Manchild 2025-06-06 11:35:00
#                                                     Safri Duo & Twocolors & Chris De Sarandy                    Head Above Water 2025-06-12 16:33:00
#                                                                                    Sam Feldt                       My Heart Goes 2025-02-21 19:09:00
#                                                      Sam Feldt & Justin Jesso & Parson James                      Lonely Tonight 2025-05-16 18:39:00
#                                                                      Sam Smith & Naughty Boy                            La La La 2025-06-12 18:39:00
#                                                                       Sanah & Kasia Kowalska                 Kiedy Umrę Kochanie 2025-03-27 20:14:00
#                                                                   Sanah & Krzysztof Zalewski                       Eviva L'arte! 2025-03-20 21:25:00
#                                                                   Sanah & Krzysztof Zalewski Eviva L'arte! (K. Przerwa-Tetmajer) 2025-01-17 08:48:00
#                                                                                   Sara James                          Tiny Heart 2025-03-09 15:29:00
#                                                                                        Sarsa                            Awantury 2025-03-30 10:32:00
#                                                                                    Sean Paul                           Like Glue 2025-03-23 18:23:00
#                                                        Sean Paul & Clean Bandit & Anne-Marie                            Rockabye 2025-06-15 09:12:00
#                                                                 Sean Paul & Enrique Iglesias                            Bailando 2025-06-13 23:41:00
#                                                  Selena Gomez & Benny Blanco & Gracie Abrams           Call Me When You Break Up 2025-02-21 09:37:00
#                                                                          Selena Gomez & Rema                           Calm Down 2025-06-16 04:20:00
#                                                                                      Sentino                          Casablanca 2025-05-13 00:05:00
#                                                                      Shaboozey & Myles Smith                         Blink Twice 2025-04-11 17:55:00
#                                                       Shaggy & R3Hab & Michael Patrick Kelly                           Rebellion 2025-06-13 00:24:00
#                                                                                       Shouse                        Call My Name 2025-03-14 16:32:00
#                                                                                       Shouse                             Sunrise 2025-05-09 18:17:00
#                                                                   Silva Bumpa & Carla Monroe                        Feel Da Same 2025-06-13 19:38:00
#                                                                             Siostry Szlachta                   Wszystkie Gwiazdy 2025-05-11 17:28:00
#                                                                                       Skolim                         Wejde Wyjdę 2025-01-15 19:15:00
#                                                                                       Slowez                            Cadillac 2025-03-10 23:22:00
#                                                                          Slowez & White 2115         Nie Będę Za Nic Przepraszać 2025-04-21 23:25:00
#                                                        Snoop Dogg & Bruno Mars & Wiz Khalifa                  Young, Wild & Free 2025-06-15 02:50:00
#                                                                      Snoop Dogg & Katy Perry                    California Gurls 2025-06-14 16:38:00
#                                                                                        Sobel                           Całe Lato 2025-06-16 23:58:00
#                                                                                        Sobel                            Kochasz? 2025-01-07 17:55:00
#                                                                                  Sobel & Oki                            Ile Lat? 2025-06-14 03:59:00
#                                                                      Sobel & Shdøw & Francis                             Cha Cha 2025-04-25 18:11:00
#                                                                    Sofia Reyes & Alan Walker                       Guaro Con Ron 2025-03-21 18:42:00
#                                                            Sonny Fodera & Clementine Douglas                             Tell Me 2025-02-07 15:31:00
#                                                                        Sophie And The Giants                         Bad Friends 2025-04-26 09:33:00
#                                                            Sophie Ellis Bextor & Felix Jaehn                 Ready For Your Love 2025-06-12 22:53:00
#                                                                                Szaran & Kize                              Klatka 2025-04-28 23:04:00
#                                                                  Tabb & Dominika Kwiatkowska                              To Ja? 2025-06-16 05:18:00
#                                                  Taco Hemingway & Bedoes & White 2115 & 2115                           Dresscode 2025-06-15 00:33:00
#                                                                  Taco Hemingway & Otsochodzi                          Nowy Kolor 2025-06-14 00:23:00
#                                                                          Taylor Swift & Zayn          I Don't Wanna Live Forever 2025-06-16 00:20:00
#                                                                                  Teddy Swims                              Guilty 2025-01-24 08:47:00
#                                                                                          Teo                            Immortal 2025-02-03 19:18:00
#                                                                                    The Drill                           The Drill 2025-03-23 19:38:00
#                                                                         The Underdog Project                            Remember 2025-06-15 19:28:00
#                                                                              Therese & Danny                         If Only You 2025-06-12 18:23:00
#                                                               Tiesto & Rita Ora & Jonas Blue                              Ritual 2025-06-15 11:26:00
#                                                                   Toby Romeo & Roger Sanchez                       Make You Mine 2025-03-07 18:54:00
#                                                                                  Tom Gregory                       Dance With Me 2025-04-04 12:33:00
#                                                                                  Tom Grennan                      Boys Don't Cry 2025-03-14 18:53:00
#                                                                            Twocolors & Barbz                                 Ums 2025-01-10 17:29:00
#                                                     Twocolors & Safri Duo & Chris De Sarandy                    Head Above Water 2025-05-30 18:19:00
#                                                                             Tyla & Sean Paul                Push 2 Start (Remix) 2025-02-21 19:41:00
#                                                                                 Tymek & Miyo                       Będzie Lepiej 2025-06-13 00:27:00
#                                                                      Unklfnkl & Jordan Grace                     Girl On The Run 2025-03-21 15:33:00
#                                                                                        Vella                         All My Love 2025-01-17 11:36:00
#                                                                                 Vixen & Tabb                         Golden Hour 2025-04-18 13:31:00
#                                                                          Vłodarski & Modelki                    Trochę Za Blisko 2025-06-15 23:50:00
#                                                                       Waima & Mefiu & Krvchy                               Honey 2025-02-10 23:09:00
#                                                                                       Wersow                                Sama 2025-05-11 11:28:00
#                                                                                   White 2115                           Lovestory 2025-05-30 03:00:00
#                                                                                   White 2115                     Opuszczony Dach 2025-01-24 19:16:00
#                                                            Wiktor Dyduła & Kasia Sienkiewicz        Nie Mówię Tak, Nie Mówię Nie 2025-03-20 17:15:00
#                                                                                Wiktoria Kida                     Mała Malusieńka 2025-04-12 05:00:00
#                                                              Wiktoria Kida & Księga Żywiołów                     Oj, Dziewczyno! 2025-04-24 19:45:00
#                                                                           Wiktoria Zwolińska                Siódme - Nie Kradnij 2025-01-10 19:38:00
#                                                                       Wiz Khalifa & 2 Chainz          We Own It (Fast & Furious) 2025-06-15 15:06:00
#                                                                      Wizthemc & Bees & Honey                        Show Me Love 2025-04-04 19:38:00
#                                                                      Wizzkids & Inusa Dawuda                 Rumours (Digi Digi) 2025-06-08 17:56:00
#                                                                                     Wołyniec                       Ostatni Dzień 2025-05-07 05:00:00
#                                                                                 Young Leosia                        Złoty Piasek 2025-03-06 18:12:00
#                                                                                Zalia & Kuban                               Kyoto 2025-06-12 14:17:00
#                                                                                 Zara Larsson                         Pretty Ugly 2025-04-25 15:32:00
#                                                                            Zdunekk & Mercury                        Gigi & Bella 2025-03-29 00:00:00
#                                                              Zdunekk & Mercury & Kaki & Json                               Milan 2025-05-09 18:39:00
#                                                                         Zedd & Ariana Grande                          Break Free 2025-06-15 10:10:00
#                                                                                       Żabson                                Lola 2025-05-26 23:50:00
#                                                                                       Żabson                       Przekaz Myśli 2025-01-20 23:27:00

# %%
# Save to HTML file 
premieres_per_station.to_html(
    "report_outputs/premieres_per_station_2025.html",
    index=False
)

# %%
# Save the cleaned dataset as df_music for further analysis
df_all.to_csv("report_outputs/df_music.csv", index=False)

# %%
# Load the music data and premieres
df_music = pd.read_csv(
    "report_outputs/df_music.csv",
    parse_dates=['date']
)

df_prem = pd.read_csv(
    "report_outputs/premieres_complete_2025.csv",
    parse_dates=['release_date']
)

# %%
# Create a full datetime for each play by combining date and time
df_music['play_dt'] = pd.to_datetime(df_music['date'].astype(str) + ' ' + df_music['time'].astype(str))

# %%
display(df_music)
display(df_prem)
# Out:
#               date      time         station  \
# 0       2024-01-01  00:00:00       Antyradio
# 1       2024-01-01  00:05:00       Antyradio
# 2       2024-01-01  00:09:00       Antyradio
# 3       2024-01-01  00:12:00       Antyradio
# 4       2024-01-01  00:17:00       Antyradio
# ...            ...       ...             ...
# 1835666 2025-06-16  23:42:00  Złote Przeboje
# 1835667 2025-06-16  23:47:00  Złote Przeboje
# 1835668 2025-06-16  23:50:00  Złote Przeboje
# 1835669 2025-06-16  23:54:00  Złote Przeboje
# 1835670 2025-06-16  23:58:00  Złote Przeboje
#
#                                         track                 artist  \
# 0                         U2 - New Year's Day                     U2
# 1              Jet - Are You Gonna Be My Girl                    Jet
# 2                     Green Day - Basket Case              Green Day
# 3              Metallica - Whiskey In The Jar              Metallica
# 4                           T.love - Warszawa                 T.love
# ...                                       ...                    ...
# 1835666                     Bon Jovi - Always               Bon Jovi
# 1835667         K.a.s.a. & Los Amigos - Maczo  K.a.s.a. & Los Amigos
# 1835668  Modern Talking - Geronimo's Cadillac         Modern Talking
# 1835669     Budka Suflera - Ratujmy Co Sie Da          Budka Suflera
# 1835670              De Su - Zycie Cudem Jest                  De Su
#
#                             title       month  hour             datetime  \
# 0                  New Year's Day  2024-01-01     0  2024-01-01 00:00:00
# 1        Are You Gonna Be My Girl  2024-01-01     0  2024-01-01 00:05:00
# 2                     Basket Case  2024-01-01     0  2024-01-01 00:09:00
# 3              Whiskey In The Jar  2024-01-01     0  2024-01-01 00:12:00
# 4                        Warszawa  2024-01-01     0  2024-01-01 00:17:00
# ...                           ...         ...   ...                  ...
# 1835666                    Always  2025-06-01    23  2025-06-16 23:42:00
# 1835667                     Maczo  2025-06-01    23  2025-06-16 23:47:00
# 1835668       Geronimo's Cadillac  2025-06-01    23  2025-06-16 23:50:00
# 1835669         Ratujmy Co Sie Da  2025-06-01    23  2025-06-16 23:54:00
# 1835670          Zycie Cudem Jest  2025-06-01    23  2025-06-16 23:58:00
#
#                     play_dt
# 0       2024-01-01 00:00:00
# 1       2024-01-01 00:05:00
# 2       2024-01-01 00:09:00
# 3       2024-01-01 00:12:00
# 4       2024-01-01 00:17:00
# ...                     ...
# 1835666 2025-06-16 23:42:00
# 1835667 2025-06-16 23:47:00
# 1835668 2025-06-16 23:50:00
# 1835669 2025-06-16 23:54:00
# 1835670 2025-06-16 23:58:00
#
# [1835671 rows x 10 columns]
#                 artists                     title release_date
# 0          Rockie Fresh                Driving 88   2025-02-19
# 1             Zoë Blade              Fallout Zone   2025-06-21
# 2            Harry Last                   Eternal   2025-07-22
# 3            Intermezzo                Iron Giant   2025-04-20
# 4         Thundermother            Dirty & Divine   2025-02-07
# ...                 ...                       ...          ...
# 52733  Roderick Newport           Pulling Us Away   2025-07-11
# 52734      Black Helium    The Animals Are Coming   2025-06-20
# 52735  Alejandro Zandes                Silhouette   2025-05-30
# 52736           akaJazy  Gaia & Physis Recordings   2025-07-04
# 52737              椎名林檎                       芒に月   2025-06-21
#
# [52738 rows x 3 columns]

# %%
# Merge music data with premiere data
df_merged = pd.merge(
    df_music,
    df_prem,
    left_on=['artist', 'title'],
    right_on=['artists', 'title'],
    how='inner'
)

# %%
df_merged
# Out:
#             date      time         station                         track  \
# 0     2024-01-03  22:47:00  Złote Przeboje  Tina Turner - Private Dancer
# 1     2024-01-03  22:47:00  Złote Przeboje  Tina Turner - Private Dancer
# 2     2024-01-03  22:47:00  Złote Przeboje  Tina Turner - Private Dancer
# 3     2024-01-07  16:48:00       Antyradio      Black Sabbath - Paranoid
# 4     2024-01-08  15:41:00  Złote Przeboje  Tina Turner - Private Dancer
# ...          ...       ...             ...                           ...
# 12495 2025-06-16  19:30:00             ZET        Alex Warren - Ordinary
# 12496 2025-06-16  19:40:00             ZET           Ed Sheeran - Azizam
# 12497 2025-06-16  19:40:00             ZET           Ed Sheeran - Azizam
# 12498 2025-06-16  23:36:00             ZET           Ed Sheeran - Azizam
# 12499 2025-06-16  23:36:00             ZET           Ed Sheeran - Azizam
#
#               artist           title       month  hour             datetime  \
# 0        Tina Turner  Private Dancer  2024-01-01    22  2024-01-03 22:47:00
# 1        Tina Turner  Private Dancer  2024-01-01    22  2024-01-03 22:47:00
# 2        Tina Turner  Private Dancer  2024-01-01    22  2024-01-03 22:47:00
# 3      Black Sabbath        Paranoid  2024-01-01    16  2024-01-07 16:48:00
# 4        Tina Turner  Private Dancer  2024-01-01    15  2024-01-08 15:41:00
# ...              ...             ...         ...   ...                  ...
# 12495    Alex Warren        Ordinary  2025-06-01    19  2025-06-16 19:30:00
# 12496     Ed Sheeran          Azizam  2025-06-01    19  2025-06-16 19:40:00
# 12497     Ed Sheeran          Azizam  2025-06-01    19  2025-06-16 19:40:00
# 12498     Ed Sheeran          Azizam  2025-06-01    23  2025-06-16 23:36:00
# 12499     Ed Sheeran          Azizam  2025-06-01    23  2025-06-16 23:36:00
#
#                   play_dt        artists release_date
# 0     2024-01-03 22:47:00    Tina Turner   2025-03-21
# 1     2024-01-03 22:47:00    Tina Turner   2025-03-21
# 2     2024-01-03 22:47:00    Tina Turner   2025-03-21
# 3     2024-01-07 16:48:00  Black Sabbath   2025-03-14
# 4     2024-01-08 15:41:00    Tina Turner   2025-03-21
# ...                   ...            ...          ...
# 12495 2025-06-16 19:30:00    Alex Warren   2025-02-07
# 12496 2025-06-16 19:40:00     Ed Sheeran   2025-04-04
# 12497 2025-06-16 19:40:00     Ed Sheeran   2025-04-04
# 12498 2025-06-16 23:36:00     Ed Sheeran   2025-04-04
# 12499 2025-06-16 23:36:00     Ed Sheeran   2025-04-04
#
# [12500 rows x 12 columns]

# %%
# Find the first play of each premiere per station
first_plays = (
    df_merged
    .groupby(
        ['station', 'artists', 'title', 'release_date'],
        as_index=False
    )
    .agg(first_play=('play_dt', 'min'))
)

first_plays
# Out:
#             station            artists            title release_date  \
# 0         Antyradio       Alice Cooper      Black Mamba   2025-04-23
# 1         Antyradio       Alice Cooper        Wild Ones   2025-06-04
# 2         Antyradio          Avantasia        The Witch   2025-02-13
# 3         Antyradio             Avatar     Captain Goat   2025-05-28
# 4         Antyradio        Biffy Clyro    A Little Love   2025-06-11
# ..              ...                ...              ...          ...
# 420             ZET  Sabrina Carpenter            Taste   2025-01-10
# 421             ZET          Sam Feldt  Time After Time   2025-05-23
# 422             ZET        Tina Turner   Private Dancer   2025-03-21
# 423             ZET        Tom Grennan     Shadowboxing   2025-01-29
# 424  Złote Przeboje        Tina Turner   Private Dancer   2025-03-21
#
#              first_play
# 0   2025-05-03 18:49:00
# 1   2025-06-03 21:38:00
# 2   2025-02-19 21:35:00
# 3   2025-05-31 19:54:00
# 4   2025-06-14 18:10:00
# ..                  ...
# 420 2024-09-25 19:31:00
# 421 2025-06-04 19:49:00
# 422 2025-04-26 16:36:00
# 423 2025-02-05 19:53:00
# 424 2024-01-03 22:47:00
#
# [425 rows x 5 columns]

# %%
# Keep only records where the first play did not happen before the release date
valid_plays = first_plays[
    first_plays['first_play'] >= first_plays['release_date']
].copy()

# Info: how many records were discarded
print(f"Discarded {len(first_plays) - len(valid_plays)} records with negative delay (play before release).")
# Out:
# Discarded 59 records with negative delay (play before release).

# %%
# Data type check
print(valid_plays.dtypes[['first_play','release_date']])
# Out:
# first_play      datetime64[ns]
# release_date            object
# dtype: object

# %%
# Convert release_date from object to datetime
valid_plays['release_date'] = pd.to_datetime(
    valid_plays['release_date']
)

# %%
# Check for unparsed (NaT) release_date values
print("Number of non-parsable release_date entries:", valid_plays['release_date'].isna().sum())
# Out:
# Number of non-parsable release_date entries: 1

# %%
# Show records where release_date could not be parsed
invalid_release_dates = valid_plays[valid_plays['release_date'].isna()][['artists', 'title', 'release_date']]
print(invalid_release_dates)
# Out:
#     artists     title release_date
# 370   Swans  Birthing          NaT

# %%
# Remove rows where release_date could not be parsed (is NaT)
valid_plays = valid_plays.dropna(subset=['release_date'])

# %%
# Show records where release_date could not be parsed - check again
invalid_release_dates = valid_plays[valid_plays['release_date'].isna()][['artists', 'title', 'release_date']]
print(invalid_release_dates)
# Out:
# Empty DataFrame
# Columns: [artists, title, release_date]
# Index: []

# %%
# Calculate latency: the delay between release date and first play
valid_plays['latency'] = valid_plays['first_play'] - valid_plays['release_date']
valid_plays
# Out:
#        station       artists            title release_date  \
# 0    Antyradio  Alice Cooper      Black Mamba   2025-04-23
# 2    Antyradio     Avantasia        The Witch   2025-02-13
# 3    Antyradio        Avatar     Captain Goat   2025-05-28
# 4    Antyradio   Biffy Clyro    A Little Love   2025-06-11
# 5    Antyradio    Billy Idol    Still Dancing   2025-02-26
# ..         ...           ...              ...          ...
# 418        ZET    Ed Sheeran           Azizam   2025-04-04
# 419        ZET    Ed Sheeran        Old Phone   2025-05-01
# 421        ZET     Sam Feldt  Time After Time   2025-05-23
# 422        ZET   Tina Turner   Private Dancer   2025-03-21
# 423        ZET   Tom Grennan     Shadowboxing   2025-01-29
#
#              first_play          latency
# 0   2025-05-03 18:49:00 10 days 18:49:00
# 2   2025-02-19 21:35:00  6 days 21:35:00
# 3   2025-05-31 19:54:00  3 days 19:54:00
# 4   2025-06-14 18:10:00  3 days 18:10:00
# 5   2025-03-04 12:51:00  6 days 12:51:00
# ..                  ...              ...
# 418 2025-04-04 19:30:00  0 days 19:30:00
# 419 2025-05-05 19:32:00  4 days 19:32:00
# 421 2025-06-04 19:49:00 12 days 19:49:00
# 422 2025-04-26 16:36:00 36 days 16:36:00
# 423 2025-02-05 19:53:00  7 days 19:53:00
#
# [365 rows x 6 columns]

# %%
# Average delay (latency) between release and first play for each radio station
radio_latency = (
    valid_plays
    .groupby('station')['latency']
    .mean()
    .reset_index()
    .sort_values('latency')
)
radio_latency
# Out:
#       station                    latency
# 9      VOX FM            7 days 17:49:30
# 4        Eska            8 days 21:58:24
# 7   RMF MAXXX 11 days 08:30:27.692307692
# 0   Antyradio 15 days 00:30:10.588235294
# 5     Jedynka           15 days 01:59:21
# 6      RMF FM 15 days 10:08:46.666666666
# 8      Trójka 18 days 02:52:18.832116788
# 10        ZET 20 days 19:18:10.909090909
# 2     Czwórka 20 days 21:49:41.428571428
# 1   Chillizet 22 days 10:09:19.459459459
# 3      Dwójka          104 days 23:17:00

# %%
# Add a column with latency in hours
radio_latency['latency_hours'] = (
    radio_latency['latency']
    .dt.total_seconds()
    .div(3600)
    .round(2)
)

# Save the latency table to HTML
radio_latency.to_html(
    os.path.join(output_folder, "radio_latency_table.html"),
    index=False
)

# %%
# Create a bar chart for average latency per station
fig = px.bar(
    radio_latency,
    x='latency_hours',
    y='station',
    orientation='h',
    title='Average premiere D=delay per Station (hours)',
    labels={'latency_hours': 'Delay (h)', 'station': 'Radio Station'},
    height=600
)

# Save the chart as an HTML file
fig.write_html(
    os.path.join(output_folder, "radio_latency_chart.html")
)

# %%
# Average premiere delay per Station (hours)

#  Color dictionary for radio stations
station_colors = {
    'Antyradio': '#e74c3c',
    'Eska': '#3498db',
    'RMF FM': '#f1c40f',
    'Radio Zet': '#9b59b6',
    # Add all your stations here...
}

# Create a bar chart with station-specific colors
fig = px.bar(
    radio_latency,
    x='latency_hours',
    y='station',
    color='station',
    color_discrete_map=station_colors,
    orientation='h',
    title='Average premiere delay per Station (hours)',
    labels={'latency_hours': 'Delay (h)', 'station': 'Radio Station'},
    height=600
)

# Save the chart as an HTML file
fig.write_html(
    os.path.join(output_folder, "radio_latency_chart_new.html")
)

# %%
# Top 10 fastest premieres on Radio

# Sort valid_plays by latency and select the top 10 fastest premieres
fastest = valid_plays.sort_values('latency').head(10).copy()

# Add latency in hours
fastest['latency_hours'] = fastest['latency'].dt.total_seconds().div(3600).round(2)

# Save the table to HTML
fastest[['artists', 'title', 'station', 'release_date', 'first_play', 'latency_hours']].to_html(
    os.path.join(output_folder, "fastest_premieres.html"),
    index=False
)

# Create a horizontal bar chart
fig = px.bar(
    fastest,
    x='latency_hours',
    y=fastest['artists'] + ' - ' + fastest['title'],
    orientation='h',
    title='Top 10 fastest premieres on Radio',
    labels={'latency_hours': 'Delay (h)', 'y': 'Track'},
    height=600
)

# Save the chart as HTML
fig.write_html(os.path.join(output_folder, "fastest_premieres_chart.html"))

# %%
# Get the 20 tracks with the shortest latency between release and first radio play
fastest = valid_plays.sort_values('latency').head(20).copy()
display(fastest)

# Fastest 50
fastest50 = valid_plays.sort_values('latency').head(50).copy()
display(fastest50)
# Out:
#        station          artists               title release_date  \
# 182       Eska       Ed Sheeran              Azizam   2025-04-04
# 319     Trójka       Lola Young           One Thing   2025-05-16
# 274     Trójka    Chappell Roan           The Giver   2025-03-14
# 299     Trójka    Greentea Peng        Stones Throw   2025-01-31
# 337     Trójka      Olivia Dean  Nice To Each Other   2025-05-30
# 186       Eska       Lola Young           One Thing   2025-05-16
# 328     Trójka      Mei Semones             Animaru   2025-05-02
# 377     Trójka   The Black Keys            Babygirl   2025-03-21
# 404     Trójka        Yung Lean        Forever Yung   2025-02-21
# 296     Trójka       Gigi Perez           Chemistry   2025-02-28
# 362     Trójka      Sports Team      Bang Bang Bang   2025-01-10
# 297     Trójka  Good Neighbours              Ripple   2025-01-24
# 185       Eska              Loi           Get Lucky   2025-06-13
# 191       Eska            Vella         All My Love   2025-01-17
# 373     Trójka      Teddy Swims      God Went Crazy   2025-06-06
# 387     Trójka        Tom Misch             Old Man   2025-03-21
# 316     Trójka     Lana Del Rey            Bluebird   2025-04-18
# 60   Chillizet     Lana Del Rey            Bluebird   2025-04-18
# 67   Chillizet      Olivia Dean  Nice To Each Other   2025-05-30
# 49   Chillizet       Ed Sheeran              Azizam   2025-04-04
#
#              first_play         latency
# 182 2025-04-04 07:09:00 0 days 07:09:00
# 319 2025-05-16 07:15:00 0 days 07:15:00
# 274 2025-03-14 10:07:00 0 days 10:07:00
# 299 2025-01-31 10:19:00 0 days 10:19:00
# 337 2025-05-30 10:20:00 0 days 10:20:00
# 186 2025-05-16 10:32:00 0 days 10:32:00
# 328 2025-05-02 10:37:00 0 days 10:37:00
# 377 2025-03-21 10:44:00 0 days 10:44:00
# 404 2025-02-21 10:48:00 0 days 10:48:00
# 296 2025-02-28 11:08:00 0 days 11:08:00
# 362 2025-01-10 11:14:00 0 days 11:14:00
# 297 2025-01-24 11:24:00 0 days 11:24:00
# 185 2025-06-13 11:35:00 0 days 11:35:00
# 191 2025-01-17 11:36:00 0 days 11:36:00
# 373 2025-06-06 11:36:00 0 days 11:36:00
# 387 2025-03-21 11:46:00 0 days 11:46:00
# 316 2025-04-18 11:52:00 0 days 11:52:00
# 60  2025-04-18 12:16:00 0 days 12:16:00
# 67  2025-05-30 12:36:00 0 days 12:36:00
# 49  2025-04-04 12:37:00 0 days 12:37:00
#        station                  artists                    title release_date  \
# 182       Eska               Ed Sheeran                   Azizam   2025-04-04
# 319     Trójka               Lola Young                One Thing   2025-05-16
# 274     Trójka            Chappell Roan                The Giver   2025-03-14
# 299     Trójka            Greentea Peng             Stones Throw   2025-01-31
# 337     Trójka              Olivia Dean       Nice To Each Other   2025-05-30
# 186       Eska               Lola Young                One Thing   2025-05-16
# 328     Trójka              Mei Semones                  Animaru   2025-05-02
# 377     Trójka           The Black Keys                 Babygirl   2025-03-21
# 404     Trójka                Yung Lean             Forever Yung   2025-02-21
# 296     Trójka               Gigi Perez                Chemistry   2025-02-28
# 362     Trójka              Sports Team           Bang Bang Bang   2025-01-10
# 297     Trójka          Good Neighbours                   Ripple   2025-01-24
# 185       Eska                      Loi                Get Lucky   2025-06-13
# 191       Eska                    Vella              All My Love   2025-01-17
# 373     Trójka              Teddy Swims           God Went Crazy   2025-06-06
# 387     Trójka                Tom Misch                  Old Man   2025-03-21
# 316     Trójka             Lana Del Rey                 Bluebird   2025-04-18
# 60   Chillizet             Lana Del Rey                 Bluebird   2025-04-18
# 67   Chillizet              Olivia Dean       Nice To Each Other   2025-05-30
# 49   Chillizet               Ed Sheeran                   Azizam   2025-04-04
# 74   Chillizet              Teddy Swims           God Went Crazy   2025-06-06
# 187       Eska               Mark Ambor                Who Knows   2025-05-09
# 226     RMF FM               Ed Sheeran                   Azizam   2025-04-04
# 179       Eska            Chappell Roan                The Giver   2025-03-14
# 216    Jedynka              Tom Grennan           Full Attention   2025-05-09
# 193       Eska             Zara Larsson              Pretty Ugly   2025-04-25
# 259     Trójka  Black Country, New Road                  Besties   2025-01-30
# 237  RMF MAXXX               Ed Sheeran                   Azizam   2025-04-04
# 15   Antyradio                    Ghost                Satanized   2025-03-05
# 31   Antyradio           Royal Republic                    Venus   2025-06-13
# 408     VOX FM            Olivia Addams                    Karma   2025-05-30
# 407     VOX FM               Ed Sheeran                   Azizam   2025-04-04
# 199    Jedynka            Chappell Roan                The Giver   2025-03-14
# 131    Czwórka             Mery Spolsky         Marysia Kowalska   2025-06-13
# 280     Trójka         Courtney Barnett               Lotta Love   2025-02-07
# 386     Trójka              Tom Grennan           Full Attention   2025-05-09
# 418        ZET               Ed Sheeran                   Azizam   2025-04-04
# 241  RMF MAXXX               Lola Young                One Thing   2025-05-16
# 228     RMF FM               Lola Young                One Thing   2025-05-16
# 14   Antyradio                Disturbed         I Will Not Break   2025-02-21
# 170    Czwórka               Wolf Alice         Bloom Baby Bloom   2025-05-17
# 364     Trójka                Stereolab          Aerial Troubles   2025-04-08
# 178       Eska             Benson Boone         Mystical Magical   2025-04-24
# 184       Eska               Ed Sheeran                 Sapphire   2025-06-05
# 166    Czwórka               Tory Lanez  Dear Kai (Prison Tapes)   2025-04-04
# 312     Trójka                 Kokoroko                  Sweetie   2025-04-10
# 294     Trójka           Fickle Friends                  Happier   2025-04-10
# 383     Trójka                The Kooks               Sunny Baby   2025-03-13
# 260     Trójka              Black Honey                   Psycho   2025-03-27
# 322     Trójka   Manic Street Preachers        Critical Thinking   2025-02-14
#
#              first_play         latency
# 182 2025-04-04 07:09:00 0 days 07:09:00
# 319 2025-05-16 07:15:00 0 days 07:15:00
# 274 2025-03-14 10:07:00 0 days 10:07:00
# 299 2025-01-31 10:19:00 0 days 10:19:00
# 337 2025-05-30 10:20:00 0 days 10:20:00
# 186 2025-05-16 10:32:00 0 days 10:32:00
# 328 2025-05-02 10:37:00 0 days 10:37:00
# 377 2025-03-21 10:44:00 0 days 10:44:00
# 404 2025-02-21 10:48:00 0 days 10:48:00
# 296 2025-02-28 11:08:00 0 days 11:08:00
# 362 2025-01-10 11:14:00 0 days 11:14:00
# 297 2025-01-24 11:24:00 0 days 11:24:00
# 185 2025-06-13 11:35:00 0 days 11:35:00
# 191 2025-01-17 11:36:00 0 days 11:36:00
# 373 2025-06-06 11:36:00 0 days 11:36:00
# 387 2025-03-21 11:46:00 0 days 11:46:00
# 316 2025-04-18 11:52:00 0 days 11:52:00
# 60  2025-04-18 12:16:00 0 days 12:16:00
# 67  2025-05-30 12:36:00 0 days 12:36:00
# 49  2025-04-04 12:37:00 0 days 12:37:00
# 74  2025-06-06 12:41:00 0 days 12:41:00
# 187 2025-05-09 13:34:00 0 days 13:34:00
# 226 2025-04-04 14:16:00 0 days 14:16:00
# 179 2025-03-14 14:33:00 0 days 14:33:00
# 216 2025-05-09 15:27:00 0 days 15:27:00
# 193 2025-04-25 15:32:00 0 days 15:32:00
# 259 2025-01-30 15:48:00 0 days 15:48:00
# 237 2025-04-04 17:11:00 0 days 17:11:00
# 15  2025-03-05 17:13:00 0 days 17:13:00
# 31  2025-06-13 17:14:00 0 days 17:14:00
# 408 2025-05-30 17:43:00 0 days 17:43:00
# 407 2025-04-04 18:13:00 0 days 18:13:00
# 199 2025-03-14 18:14:00 0 days 18:14:00
# 131 2025-06-13 18:48:00 0 days 18:48:00
# 280 2025-02-07 19:14:00 0 days 19:14:00
# 386 2025-05-09 19:23:00 0 days 19:23:00
# 418 2025-04-04 19:30:00 0 days 19:30:00
# 241 2025-05-16 19:31:00 0 days 19:31:00
# 228 2025-05-16 19:31:00 0 days 19:31:00
# 14  2025-02-21 19:38:00 0 days 19:38:00
# 170 2025-05-17 19:39:00 0 days 19:39:00
# 364 2025-04-08 22:06:00 0 days 22:06:00
# 178 2025-04-25 08:09:00 1 days 08:09:00
# 184 2025-06-06 09:34:00 1 days 09:34:00
# 166 2025-04-05 10:01:00 1 days 10:01:00
# 312 2025-04-11 10:18:00 1 days 10:18:00
# 294 2025-04-11 10:49:00 1 days 10:49:00
# 383 2025-03-14 11:22:00 1 days 11:22:00
# 260 2025-03-28 11:37:00 1 days 11:37:00
# 322 2025-02-15 13:54:00 1 days 13:54:00

# %%
# Convert the latency to hours, rounded to two decimal places
fastest['latency_hours'] = fastest['latency'].dt.total_seconds().div(3600).round(2)
display(fastest)
# Out:
#        station          artists               title release_date  \
# 182       Eska       Ed Sheeran              Azizam   2025-04-04
# 319     Trójka       Lola Young           One Thing   2025-05-16
# 274     Trójka    Chappell Roan           The Giver   2025-03-14
# 299     Trójka    Greentea Peng        Stones Throw   2025-01-31
# 337     Trójka      Olivia Dean  Nice To Each Other   2025-05-30
# 186       Eska       Lola Young           One Thing   2025-05-16
# 328     Trójka      Mei Semones             Animaru   2025-05-02
# 377     Trójka   The Black Keys            Babygirl   2025-03-21
# 404     Trójka        Yung Lean        Forever Yung   2025-02-21
# 296     Trójka       Gigi Perez           Chemistry   2025-02-28
# 362     Trójka      Sports Team      Bang Bang Bang   2025-01-10
# 297     Trójka  Good Neighbours              Ripple   2025-01-24
# 185       Eska              Loi           Get Lucky   2025-06-13
# 191       Eska            Vella         All My Love   2025-01-17
# 373     Trójka      Teddy Swims      God Went Crazy   2025-06-06
# 387     Trójka        Tom Misch             Old Man   2025-03-21
# 316     Trójka     Lana Del Rey            Bluebird   2025-04-18
# 60   Chillizet     Lana Del Rey            Bluebird   2025-04-18
# 67   Chillizet      Olivia Dean  Nice To Each Other   2025-05-30
# 49   Chillizet       Ed Sheeran              Azizam   2025-04-04
#
#              first_play         latency  latency_hours
# 182 2025-04-04 07:09:00 0 days 07:09:00           7.15
# 319 2025-05-16 07:15:00 0 days 07:15:00           7.25
# 274 2025-03-14 10:07:00 0 days 10:07:00          10.12
# 299 2025-01-31 10:19:00 0 days 10:19:00          10.32
# 337 2025-05-30 10:20:00 0 days 10:20:00          10.33
# 186 2025-05-16 10:32:00 0 days 10:32:00          10.53
# 328 2025-05-02 10:37:00 0 days 10:37:00          10.62
# 377 2025-03-21 10:44:00 0 days 10:44:00          10.73
# 404 2025-02-21 10:48:00 0 days 10:48:00          10.80
# 296 2025-02-28 11:08:00 0 days 11:08:00          11.13
# 362 2025-01-10 11:14:00 0 days 11:14:00          11.23
# 297 2025-01-24 11:24:00 0 days 11:24:00          11.40
# 185 2025-06-13 11:35:00 0 days 11:35:00          11.58
# 191 2025-01-17 11:36:00 0 days 11:36:00          11.60
# 373 2025-06-06 11:36:00 0 days 11:36:00          11.60
# 387 2025-03-21 11:46:00 0 days 11:46:00          11.77
# 316 2025-04-18 11:52:00 0 days 11:52:00          11.87
# 60  2025-04-18 12:16:00 0 days 12:16:00          12.27
# 67  2025-05-30 12:36:00 0 days 12:36:00          12.60
# 49  2025-04-04 12:37:00 0 days 12:37:00          12.62

# %%
# Save the table of the 20 fastest premieres to an HTML file
fastest[['artists', 'title', 'station', 'release_date', 'first_play', 'latency_hours']].to_html(
    os.path.join(output_folder, "fastest_20_premieres.html"),
    index=False
)

# %%
# Create a horizontal bar chart of the 20 fastest premieres, colored by station
fig = px.bar(
    fastest,
    x='latency_hours',
    y=fastest['artists'] + ' – ' + fastest['title'],
    color='station',
    orientation='h',
    title='Top 20 fastest premieres on Radio',
    labels={'latency_hours': 'Delay (h)', 'y': 'Track'},
    height=800
)
fig.update_layout(yaxis={'categoryorder': 'total ascending'})

# Save the chart to HTML
fig.write_html(os.path.join(output_folder, "fastest_20_premieres_chart.html"))

# %%
# Top 20 fastest premieres by radio statio

fastest['latency_hours'] = fastest['latency'].dt.total_seconds().div(3600).round(2)
fastest['track_label'] = fastest['artists'] + ' – ' + fastest['title']

fig = px.bar(
    fastest,
    x='latency_hours',
    y='track_label',
    color='station',
    facet_col='station',
    facet_col_wrap=2,         # number of panels per row
    orientation='h',
    title='Top 20 fastest premieres by radio station',
    labels={'latency_hours': 'Delay (h)', 'track_label': 'Track'}
)
# Remove the legend, since color and facet are the same
fig.update_layout(showlegend=False)

# Save to HTML
fig.write_html(os.path.join(output_folder, "fastest_20_faceted.html"))

# %%
# Comparison of release date vs. first radio play

fastest_plot = fastest.copy()
fastest_plot['release_dt'] = pd.to_datetime(fastest_plot['release_date'])
fastest_plot['first_play_dt'] = fastest_plot['first_play']

fig = px.scatter(
    fastest_plot,
    x='release_dt',
    y='first_play_dt',
    color='station',
    symbol='station',
    hover_data=['artists', 'title'],
    title='Comparison of release date vs. first radio play'
)

fig.write_html(os.path.join(output_folder, "fastest_scatter.html"))

# %%
# Top 20 fastest premieres per station

# Output folder
output_subfolder = os.path.join(output_folder, "fastest_by_station")
os.makedirs(output_subfolder, exist_ok=True)

for station, grp in fastest.groupby('station'):
    fig = px.bar(
        grp,
        x='latency_hours',
        y=grp['artists'] + ' - ' + grp['title'],
        orientation='h',
        title=f'Top 20 fastest premieres - {station}',
        labels={'latency_hours': 'Delay (h)', 'y': 'Track'},
        height=600
    )
    fname = f"fastest_20_{station.replace(' ', '_')}.html"
    fig.write_html(os.path.join(output_subfolder, fname))

# %%
# For the top 20 fastest premieres, add a label column combining artist, title, and station
fastest['label'] = (
    fastest['artists'] + ' - ' +
    fastest['title'] + ' (' + fastest['station'] + ')'
)

fastest
# Out:
#        station          artists               title release_date  \
# 182       Eska       Ed Sheeran              Azizam   2025-04-04
# 319     Trójka       Lola Young           One Thing   2025-05-16
# 274     Trójka    Chappell Roan           The Giver   2025-03-14
# 299     Trójka    Greentea Peng        Stones Throw   2025-01-31
# 337     Trójka      Olivia Dean  Nice To Each Other   2025-05-30
# 186       Eska       Lola Young           One Thing   2025-05-16
# 328     Trójka      Mei Semones             Animaru   2025-05-02
# 377     Trójka   The Black Keys            Babygirl   2025-03-21
# 404     Trójka        Yung Lean        Forever Yung   2025-02-21
# 296     Trójka       Gigi Perez           Chemistry   2025-02-28
# 362     Trójka      Sports Team      Bang Bang Bang   2025-01-10
# 297     Trójka  Good Neighbours              Ripple   2025-01-24
# 185       Eska              Loi           Get Lucky   2025-06-13
# 191       Eska            Vella         All My Love   2025-01-17
# 373     Trójka      Teddy Swims      God Went Crazy   2025-06-06
# 387     Trójka        Tom Misch             Old Man   2025-03-21
# 316     Trójka     Lana Del Rey            Bluebird   2025-04-18
# 60   Chillizet     Lana Del Rey            Bluebird   2025-04-18
# 67   Chillizet      Olivia Dean  Nice To Each Other   2025-05-30
# 49   Chillizet       Ed Sheeran              Azizam   2025-04-04
#
#              first_play         latency  latency_hours  \
# 182 2025-04-04 07:09:00 0 days 07:09:00           7.15
# 319 2025-05-16 07:15:00 0 days 07:15:00           7.25
# 274 2025-03-14 10:07:00 0 days 10:07:00          10.12
# 299 2025-01-31 10:19:00 0 days 10:19:00          10.32
# 337 2025-05-30 10:20:00 0 days 10:20:00          10.33
# 186 2025-05-16 10:32:00 0 days 10:32:00          10.53
# 328 2025-05-02 10:37:00 0 days 10:37:00          10.62
# 377 2025-03-21 10:44:00 0 days 10:44:00          10.73
# 404 2025-02-21 10:48:00 0 days 10:48:00          10.80
# 296 2025-02-28 11:08:00 0 days 11:08:00          11.13
# 362 2025-01-10 11:14:00 0 days 11:14:00          11.23
# 297 2025-01-24 11:24:00 0 days 11:24:00          11.40
# 185 2025-06-13 11:35:00 0 days 11:35:00          11.58
# 191 2025-01-17 11:36:00 0 days 11:36:00          11.60
# 373 2025-06-06 11:36:00 0 days 11:36:00          11.60
# 387 2025-03-21 11:46:00 0 days 11:46:00          11.77
# 316 2025-04-18 11:52:00 0 days 11:52:00          11.87
# 60  2025-04-18 12:16:00 0 days 12:16:00          12.27
# 67  2025-05-30 12:36:00 0 days 12:36:00          12.60
# 49  2025-04-04 12:37:00 0 days 12:37:00          12.62
#
#                           track_label  \
# 182               Ed Sheeran – Azizam
# 319            Lola Young – One Thing
# 274         Chappell Roan – The Giver
# 299      Greentea Peng – Stones Throw
# 337  Olivia Dean – Nice To Each Other
# 186            Lola Young – One Thing
# 328             Mei Semones – Animaru
# 377         The Black Keys – Babygirl
# 404          Yung Lean – Forever Yung
# 296            Gigi Perez – Chemistry
# 362      Sports Team – Bang Bang Bang
# 297          Good Neighbours – Ripple
# 185                   Loi – Get Lucky
# 191               Vella – All My Love
# 373      Teddy Swims – God Went Crazy
# 387               Tom Misch – Old Man
# 316           Lana Del Rey – Bluebird
# 60            Lana Del Rey – Bluebird
# 67   Olivia Dean – Nice To Each Other
# 49                Ed Sheeran – Azizam
#
#                                             label
# 182                    Ed Sheeran - Azizam (Eska)
# 319               Lola Young - One Thing (Trójka)
# 274            Chappell Roan - The Giver (Trójka)
# 299         Greentea Peng - Stones Throw (Trójka)
# 337     Olivia Dean - Nice To Each Other (Trójka)
# 186                 Lola Young - One Thing (Eska)
# 328                Mei Semones - Animaru (Trójka)
# 377            The Black Keys - Babygirl (Trójka)
# 404             Yung Lean - Forever Yung (Trójka)
# 296               Gigi Perez - Chemistry (Trójka)
# 362         Sports Team - Bang Bang Bang (Trójka)
# 297             Good Neighbours - Ripple (Trójka)
# 185                        Loi - Get Lucky (Eska)
# 191                    Vella - All My Love (Eska)
# 373         Teddy Swims - God Went Crazy (Trójka)
# 387                  Tom Misch - Old Man (Trójka)
# 316              Lana Del Rey - Bluebird (Trójka)
# 60            Lana Del Rey - Bluebird (Chillizet)
# 67   Olivia Dean - Nice To Each Other (Chillizet)
# 49                Ed Sheeran - Azizam (Chillizet)

# %%
# List of all unique radio stations
unique_stations = df_music['station'].unique()

unique_stations
# Out:
# array(['Antyradio', 'Chillizet', 'Czwórka', 'Dwójka', 'Eska', 'Jedynka',
#        'RMF Classic', 'RMF FM', 'RMF MAXXX', 'Trójka', 'VOX FM', 'ZET',
#        'Złote Przeboje'], dtype=object)

# %%
# Set colors for each radio station
station_colors = {
    'Jedynka': '#F48F20',         # orange from Jedynka's logo  
    'Dwójka': '#00994C',          # green - Dwójka  
    'Trójka': '#E0007D',          # magenta - Trójka  
    'Czwórka': '#FFD100',         # yellow - Czwórka  
    'ZET': '#C8102E',             # red - ZET  
    'Złote Przeboje': '#DEAB4A',  # gold - Złote Przeboje  
    'Antyradio': '#CE2029',       # red-black - Antyradio  
    'RMF MAXXX': '#E600CC',       # pink - RMF Maxxx  
    'Chillizet': '#CC00FF',       # purple-pink - Chilli Zet  
    'RMF FM': '#FFD700',          # yellow - RMF  
    'VOX FM': '#002663',          # dark blue - Vox FM  
    'Eska': '#FF6600',            # orange - Eska  
    'RMF Classic': '#7F1F30'      # burgundy - RMF Classic  
}

# %%
# Create a label directly from artist, title, and station
fastest['label'] = fastest['artists'] + ' - ' + fastest['title'] + ' (' + fastest['station'] + ')'

# Create a list of labels, sorted alphabetically by track name
labels_order = sorted(
    fastest['label'].unique(),
    key=lambda lab: lab.split('(')[0].strip().lower()
)

# %%
# Bar chart - the top 20 tracks with the shortest delay from release to first radio play, with colors mapped to stations and labels sorted alphabetically by track

# fastest: df with columns latency_hours, label and station
# labels_order: list of labels sorted alphabetically by track
# station_colors: dictionary mapping station names to colors

fig = px.bar(
    fastest,
    x='latency_hours',
    y='label',
    color='station',
    color_discrete_map=station_colors,
    orientation='h',
    category_orders={'label': labels_order},  # sort labels alphabetically
    title='Top 20 fastest premieres on Radio',
    labels={'latency_hours': 'Delay since release (h)', 'label': 'Track (Station)'},
    height=800
)

fig.write_html(os.path.join(output_folder, "fastest_20_colored_sorted.html"))

# %%
# Add latency in hours
fastest50['latency_hours'] = (
    fastest50['latency']
    .dt.total_seconds()
    .div(3600)
    .round(2)
)

# Create a label combining artist, title, and station in parentheses
fastest50['label'] = (
    fastest50['artists'] + ' - ' +
    fastest50['title'] + ' (' + fastest50['station'] + ')'
)

# Labels order
labels_order = sorted(
    fastest50['label'].unique(),
    key=lambda lab: lab.rsplit('(',1)[0].strip().lower()
)

# %%
# Bar chart - the 50 tracks with the shortest delay from release to first radio play, with station-based colors and alphabetically sorted labels


fig = px.bar(
    fastest50,
    x='latency_hours',
    y='label',
    color='station',
    color_discrete_map=station_colors,
    orientation='h',
    category_orders={'label': labels_order},
    title='Top 50 fastest premieres on radio',
    labels={'latency_hours': 'Delay (h)', 'label': 'Track (Station)'},
    height=1200
)

fig.write_html(os.path.join(output_folder, "fastest50_premieres_chart.html"))

# %%
# Top 50 fastest premieres on Radio
from collections import Counter

# data: fastest50, labels_order, station_colors
fig = px.bar(
    fastest50,
    x='latency_hours',
    y='label',
    color='station',
    color_discrete_map=station_colors,
    orientation='h',
    category_orders={'label': labels_order},
    title='Top 50 fastest premieres on Radio',
    labels={'latency_hours': 'Delay (h)', 'label': 'Track (Station)'},
    height=1200
)

# Helper function to extract the track title from the label
def extract_title(label):
    return label.split('-', 1)[-1].split('(')[0].strip()

# Find duplicate titles among the fastest premieres
titles = [extract_title(lab) for lab in labels_order]
dupe_titles = [t for t, c in Counter(titles).items() if c > 1]

# Colors for highlighting duplicate titles
background_colors = [
    "rgba(50,200,50,0.15)",   # green
    "rgba(50,50,200,0.15)",   # blue
    "rgba(200,200,50,0.15)",  # yellow
    "rgba(200,50,200,0.15)",  # violet
    "rgba(200,50,50,0.15)",   # red
    "rgba(50,200,200,0.15)",  # turquoise
]

# Highlight rows with duplicate titles by drawing a colored rectangle behind them
for i, t in enumerate(dupe_titles):
    idxs = [j for j, lab in enumerate(labels_order) if extract_title(lab) == t]
    if not idxs:
        continue
    y0 = labels_order[min(idxs)]
    # If not the last on the list, y1 is the next label; if last, y1 = y0 (no shade)
    if max(idxs) + 1 < len(labels_order):
        y1 = labels_order[max(idxs) + 1]
    else:
        y1 = y0
    fig.add_shape(
        type="rect",
        xref="paper", yref="y",
        x0=0, x1=1, y0=y0, y1=y1,
        fillcolor=background_colors[i % len(background_colors)],
        line=dict(width=0),
        layer="below"
    )

fig.write_html(os.path.join(output_folder, "fastest50_premieres_chart_highlighted.html"))

# %% [markdown]
# ### 2025 Top Hits

# %%
df_prem
# Out:
#                 artists                     title release_date
# 0          Rockie Fresh                Driving 88   2025-02-19
# 1             Zoë Blade              Fallout Zone   2025-06-21
# 2            Harry Last                   Eternal   2025-07-22
# 3            Intermezzo                Iron Giant   2025-04-20
# 4         Thundermother            Dirty & Divine   2025-02-07
# ...                 ...                       ...          ...
# 52733  Roderick Newport           Pulling Us Away   2025-07-11
# 52734      Black Helium    The Animals Are Coming   2025-06-20
# 52735  Alejandro Zandes                Silhouette   2025-05-30
# 52736           akaJazy  Gaia & Physis Recordings   2025-07-04
# 52737              椎名林檎                       芒に月   2025-06-21
#
# [52738 rows x 3 columns]

# %%
# Songs with premieres in 2025

## datetime change
df_prem['release_date'] = pd.to_datetime(
    df_prem['release_date'],
    errors='coerce'
)

df_prem2025 = df_prem[df_prem['release_date'].dt.year == 2025].copy()
df_prem2025
# Out:
#                 artists                     title release_date
# 0          Rockie Fresh                Driving 88   2025-02-19
# 1             Zoë Blade              Fallout Zone   2025-06-21
# 2            Harry Last                   Eternal   2025-07-22
# 3            Intermezzo                Iron Giant   2025-04-20
# 4         Thundermother            Dirty & Divine   2025-02-07
# ...                 ...                       ...          ...
# 52733  Roderick Newport           Pulling Us Away   2025-07-11
# 52734      Black Helium    The Animals Are Coming   2025-06-20
# 52735  Alejandro Zandes                Silhouette   2025-05-30
# 52736           akaJazy  Gaia & Physis Recordings   2025-07-04
# 52737              椎名林檎                       芒に月   2025-06-21
#
# [52473 rows x 3 columns]

# %%
# Total number of plays per song
total_plays = (
    df_music
    .groupby(['artist', 'title'])
    .size()
    .reset_index(name='total_plays')
)

# %%
# Sort songs by total number of plays, descending
total_plays_sorted_dsc = total_plays.sort_values(
    by='total_plays',
    ascending=False
)
total_plays_sorted_dsc.head(10)
# Out:
#                   artist                       title  total_plays
# 5714             Artemas  I Like The Way You Kiss Me         3344
# 25473           Dua Lipa                     Houdini         3032
# 93510         The Kolors      Un Ragazzo Una Ragazza         2847
# 16354      Chappell Roan            Good Luck, Babe!         2666
# 21450     Daria Zawiałow       Złamane Serce Jest Ok         2571
# 89375  Sylwia Grzeszczak                   Och I Ach         2532
# 45611             Kaeyra                        Sour         2524
# 27938             Eminem                     Houdini         2462
# 38342             Hozier                   Too Sweet         2352
# 93503         The Kolors                  Italodisco         2286

# %%
# Top hits from 2025
hits2025 = (
    total_plays
    .merge(
        df_prem2025[['artists', 'title']],
        left_on=['artist', 'title'],
        right_on=['artists', 'title'],
        how='inner'
    )
    .sort_values('total_plays', ascending=False)
    .head(50)
    .reset_index(drop=True)
)
hits2025
# Out:
#                artist                      title  total_plays  \
# 0          Ed Sheeran                     Azizam         1288
# 1          Ed Sheeran                     Azizam         1288
# 2         Alex Warren                   Ordinary         1163
# 3   Sabrina Carpenter                      Taste          948
# 4   Sabrina Carpenter                      Taste          948
# 5             Doechii                    Anxiety          752
# 6        Benson Boone           Mystical Magical          208
# 7        Youth Lagoon                Speed Freak          201
# 8               Vella                All My Love          155
# 9               Vella                All My Love          155
# 10       Abor & Tynna                     Baller          140
# 11         Billy Idol              Still Dancing          117
# 12    The Blue Stones                 Come Apart          116
# 13    The Blue Stones                 Come Apart          116
# 14              Ghost                  Satanized          106
# 15        Tina Turner             Private Dancer          101
# 16        Tina Turner             Private Dancer          101
# 17        Tina Turner             Private Dancer          101
# 18        Bryan Adams          Make Up Your Mind           98
# 19     Britney Spears                      Lucky           80
# 20        Dina Summer                 Girls Gang           78
# 21      Chappell Roan                  The Giver           77
# 22      Chappell Roan                  The Giver           77
# 23      Chappell Roan                  The Giver           77
# 24      Chappell Roan                  The Giver           77
# 25      Chappell Roan                  The Giver           77
# 26         Polo & Pan                 The Mirror           77
# 27      Chappell Roan                  The Giver           77
# 28      Chappell Roan                  The Giver           77
# 29      Chappell Roan                  The Giver           77
# 30      Chappell Roan                  The Giver           77
# 31      Chappell Roan                  The Giver           77
# 32         Polo & Pan                 The Mirror           77
# 33      Chappell Roan                  The Giver           77
# 34      Chappell Roan                  The Giver           77
# 35      Chappell Roan                  The Giver           77
# 36      Chappell Roan                  The Giver           77
# 37      Chappell Roan                  The Giver           77
# 38      Black Sabbath                   Paranoid           70
# 39         Lola Young                  One Thing           69
# 40         Lola Young                  One Thing           69
# 41         Ed Sheeran                  Old Phone           64
# 42         Ed Sheeran                  Old Phone           64
# 43       Rise Against               Prizefighter           62
# 44        Tom Grennan               Shadowboxing           62
# 45       Rise Against               Prizefighter           62
# 46        Tom Grennan               Shadowboxing           62
# 47              Leony  By Your Side (In My Mind)           59
# 48              Leony  By Your Side (In My Mind)           59
# 49              Leony  By Your Side (In My Mind)           59
#
#               artists
# 0          Ed Sheeran
# 1          Ed Sheeran
# 2         Alex Warren
# 3   Sabrina Carpenter
# 4   Sabrina Carpenter
# 5             Doechii
# 6        Benson Boone
# 7        Youth Lagoon
# 8               Vella
# 9               Vella
# 10       Abor & Tynna
# 11         Billy Idol
# 12    The Blue Stones
# 13    The Blue Stones
# 14              Ghost
# 15        Tina Turner
# 16        Tina Turner
# 17        Tina Turner
# 18        Bryan Adams
# 19     Britney Spears
# 20        Dina Summer
# 21      Chappell Roan
# 22      Chappell Roan
# 23      Chappell Roan
# 24      Chappell Roan
# 25      Chappell Roan
# 26         Polo & Pan
# 27      Chappell Roan
# 28      Chappell Roan
# 29      Chappell Roan
# 30      Chappell Roan
# 31      Chappell Roan
# 32         Polo & Pan
# 33      Chappell Roan
# 34      Chappell Roan
# 35      Chappell Roan
# 36      Chappell Roan
# 37      Chappell Roan
# 38      Black Sabbath
# 39         Lola Young
# 40         Lola Young
# 41         Ed Sheeran
# 42         Ed Sheeran
# 43       Rise Against
# 44        Tom Grennan
# 45       Rise Against
# 46        Tom Grennan
# 47              Leony
# 48              Leony
# 49              Leony

# %%
# Create full play datetime from date and time
df_music['play_dt'] = pd.to_datetime(
    df_music['date'].astype(str) + ' ' + df_music['time'].astype(str),
    errors='coerce'
)

# %%
# Filter music plays to only 2025 hits
df_hits = df_music.merge(
    hits2025[['artist', 'title']],
    on=['artist', 'title'],
    how='inner'
)
df_hits
# Out:
#             date      time         station                         track  \
# 0     2024-01-03  22:47:00  Złote Przeboje  Tina Turner - Private Dancer
# 1     2024-01-03  22:47:00  Złote Przeboje  Tina Turner - Private Dancer
# 2     2024-01-03  22:47:00  Złote Przeboje  Tina Turner - Private Dancer
# 3     2024-01-07  16:48:00       Antyradio      Black Sabbath - Paranoid
# 4     2024-01-08  15:41:00  Złote Przeboje  Tina Turner - Private Dancer
# ...          ...       ...             ...                           ...
# 10325 2025-06-16  19:30:00             ZET        Alex Warren - Ordinary
# 10326 2025-06-16  19:40:00             ZET           Ed Sheeran - Azizam
# 10327 2025-06-16  19:40:00             ZET           Ed Sheeran - Azizam
# 10328 2025-06-16  23:36:00             ZET           Ed Sheeran - Azizam
# 10329 2025-06-16  23:36:00             ZET           Ed Sheeran - Azizam
#
#               artist           title       month  hour             datetime  \
# 0        Tina Turner  Private Dancer  2024-01-01    22  2024-01-03 22:47:00
# 1        Tina Turner  Private Dancer  2024-01-01    22  2024-01-03 22:47:00
# 2        Tina Turner  Private Dancer  2024-01-01    22  2024-01-03 22:47:00
# 3      Black Sabbath        Paranoid  2024-01-01    16  2024-01-07 16:48:00
# 4        Tina Turner  Private Dancer  2024-01-01    15  2024-01-08 15:41:00
# ...              ...             ...         ...   ...                  ...
# 10325    Alex Warren        Ordinary  2025-06-01    19  2025-06-16 19:30:00
# 10326     Ed Sheeran          Azizam  2025-06-01    19  2025-06-16 19:40:00
# 10327     Ed Sheeran          Azizam  2025-06-01    19  2025-06-16 19:40:00
# 10328     Ed Sheeran          Azizam  2025-06-01    23  2025-06-16 23:36:00
# 10329     Ed Sheeran          Azizam  2025-06-01    23  2025-06-16 23:36:00
#
#                   play_dt
# 0     2024-01-03 22:47:00
# 1     2024-01-03 22:47:00
# 2     2024-01-03 22:47:00
# 3     2024-01-07 16:48:00
# 4     2024-01-08 15:41:00
# ...                   ...
# 10325 2025-06-16 19:30:00
# 10326 2025-06-16 19:40:00
# 10327 2025-06-16 19:40:00
# 10328 2025-06-16 23:36:00
# 10329 2025-06-16 23:36:00
#
# [10330 rows x 10 columns]

# %%
# Find the first play of each 2025 hit per station
first_by_station = (
    df_hits
    .groupby(['artist', 'title', 'station'], as_index=False)
    .agg(first_play=('play_dt', 'min'))
)
first_by_station
# Out:
#           artist        title    station          first_play
# 0   Abor & Tynna       Baller       Eska 2025-05-23 18:20:00
# 1   Abor & Tynna       Baller  RMF MAXXX 2025-05-22 19:33:00
# 2    Alex Warren     Ordinary    Czwórka 2025-05-12 08:24:00
# 3    Alex Warren     Ordinary       Eska 2025-04-04 06:58:00
# 4    Alex Warren     Ordinary    Jedynka 2025-03-24 14:51:00
# ..           ...          ...        ...                 ...
# 76         Vella  All My Love    Jedynka 2025-02-10 18:49:00
# 77         Vella  All My Love  RMF MAXXX 2025-01-25 19:05:00
# 78  Youth Lagoon  Speed Freak  Chillizet 2025-02-06 13:10:00
# 79  Youth Lagoon  Speed Freak    Czwórka 2025-01-26 08:28:00
# 80  Youth Lagoon  Speed Freak     Trójka 2025-01-11 17:18:00
#
# [81 rows x 4 columns]

# %%
# Find the very first station and time each 2025 hit was played
first_overall = (
    first_by_station
    .sort_values('first_play')
    .groupby(['artist', 'title'], as_index=False)
    .first()
    .rename(columns={'station': 'premiere_station', 'first_play': 'premiere_time'})
)

first_overall
# Out:
#                artist                      title premiere_station  \
# 0        Abor & Tynna                     Baller        RMF MAXXX
# 1         Alex Warren                   Ordinary          Jedynka
# 2        Benson Boone           Mystical Magical             Eska
# 3          Billy Idol              Still Dancing           Trójka
# 4       Black Sabbath                   Paranoid        Antyradio
# 5      Britney Spears                      Lucky           VOX FM
# 6         Bryan Adams          Make Up Your Mind           Trójka
# 7       Chappell Roan                  The Giver           Trójka
# 8         Dina Summer                 Girls Gang          Czwórka
# 9             Doechii                    Anxiety             Eska
# 10         Ed Sheeran                     Azizam             Eska
# 11         Ed Sheeran                  Old Phone           RMF FM
# 12              Ghost                  Satanized        Antyradio
# 13              Leony  By Your Side (In My Mind)        Chillizet
# 14         Lola Young                  One Thing           Trójka
# 15         Polo & Pan                 The Mirror          Czwórka
# 16       Rise Against               Prizefighter        Antyradio
# 17  Sabrina Carpenter                      Taste           Trójka
# 18    The Blue Stones                 Come Apart        Antyradio
# 19        Tina Turner             Private Dancer   Złote Przeboje
# 20        Tom Grennan               Shadowboxing        RMF MAXXX
# 21              Vella                All My Love             Eska
# 22       Youth Lagoon                Speed Freak           Trójka
#
#          premiere_time
# 0  2025-05-22 19:33:00
# 1  2025-03-24 14:51:00
# 2  2025-04-25 08:09:00
# 3  2025-03-03 14:18:00
# 4  2024-01-07 16:48:00
# 5  2024-01-10 12:27:00
# 6  2025-03-13 04:44:00
# 7  2025-03-14 10:07:00
# 8  2024-10-03 19:33:00
# 9  2025-03-04 19:14:00
# 10 2025-04-04 07:09:00
# 11 2025-05-03 09:45:00
# 12 2025-03-05 17:13:00
# 13 2025-02-05 18:33:00
# 14 2025-05-16 07:15:00
# 15 2025-02-24 12:19:00
# 16 2025-04-12 18:53:00
# 17 2024-08-23 17:29:00
# 18 2025-02-08 19:18:00
# 19 2024-01-03 22:47:00
# 20 2025-01-31 18:13:00
# 21 2025-01-17 11:36:00
# 22 2025-01-11 17:18:00

# %%
# Count the number of 2025 hits premiered by each station
premiere_counts = (
    first_overall['premiere_station']
    .value_counts()
    .rename_axis('station')
    .reset_index(name='hit_count')
)

premiere_counts
# Out:
#           station  hit_count
# 0          Trójka          6
# 1            Eska          4
# 2       Antyradio          4
# 3       RMF MAXXX          2
# 4         Czwórka          2
# 5         Jedynka          1
# 6          VOX FM          1
# 7          RMF FM          1
# 8       Chillizet          1
# 9  Złote Przeboje          1

# %%
# Number of 2025 Hits premiered by each station

# Save the premiere counts table to HTML
premiere_counts.to_html(os.path.join(output_folder, "hit_premieres_2025_per_station.html"), index=False)

# Create a horizontal bar chart of 2025 hit premieres per station
fig = px.bar(
    premiere_counts,
    x='hit_count',
    y='station',
    orientation='h',
    title='Number of 2025 Hits premiered by each station',
    labels={'hit_count': 'Number of Hits', 'station': 'Radio Station'},
    color='station',
    color_discrete_map=station_colors
)

# Save the chart as an HTML file
fig.write_html(os.path.join(output_folder, "hit_premieres_2025_chart.html"))

# %%
# What songs are there

# Merge first_by_station with release_date from df_prem2025
df_hits_full = first_by_station.merge(
    df_prem2025[['artists', 'title', 'release_date']],
    left_on=['artist', 'title'],
    right_on=['artists', 'title'],
    how='left'
)

# Convert release_date to datetime
df_hits_full['release_dt'] = pd.to_datetime(
    df_hits_full['release_date'],
    errors='coerce'
)

# Filter only plays after the official release date
df_hits_valid = df_hits_full[
    df_hits_full['first_play'] >= df_hits_full['release_dt']
].copy()

# Find the premiere station (first play after release)
first_overall = (
    df_hits_valid
    .sort_values('first_play')
    .groupby(['artist', 'title'], as_index=False)
    .first()
    .rename(columns={
        'station': 'premiere_station',
        'first_play': 'premiere_time'
    })
)

# Merge with total_plays and prepare for sunburst
station_hits = first_overall.merge(
    total_plays,
    on=['artist', 'title'],
    how='left'
)

# %%
# Merges the first overall premieres with total play counts for each hit

station_hits = first_overall.merge(
    total_plays,
    on=['artist', 'title'],
    how='left'
)

station_hits
# Out:
#              artist                      title premiere_station  \
# 0      Abor & Tynna                     Baller        RMF MAXXX
# 1       Alex Warren                   Ordinary          Jedynka
# 2      Benson Boone           Mystical Magical             Eska
# 3        Billy Idol              Still Dancing           Trójka
# 4       Bryan Adams          Make Up Your Mind           Trójka
# 5     Chappell Roan                  The Giver           Trójka
# 6           Doechii                    Anxiety           Trójka
# 7        Ed Sheeran                     Azizam             Eska
# 8        Ed Sheeran                  Old Phone           RMF FM
# 9             Ghost                  Satanized        Antyradio
# 10            Leony  By Your Side (In My Mind)        Chillizet
# 11       Lola Young                  One Thing           Trójka
# 12       Polo & Pan                 The Mirror          Czwórka
# 13     Rise Against               Prizefighter        Antyradio
# 14  The Blue Stones                 Come Apart        Antyradio
# 15      Tina Turner             Private Dancer              ZET
# 16      Tom Grennan               Shadowboxing        RMF MAXXX
# 17            Vella                All My Love             Eska
# 18     Youth Lagoon                Speed Freak           Trójka
#
#          premiere_time          artists release_date release_dt  total_plays
# 0  2025-05-22 19:33:00     Abor & Tynna   2025-05-15 2025-05-15          140
# 1  2025-03-24 14:51:00      Alex Warren   2025-02-07 2025-02-07         1163
# 2  2025-04-25 08:09:00     Benson Boone   2025-04-24 2025-04-24          208
# 3  2025-03-03 14:18:00       Billy Idol   2025-02-26 2025-02-26          117
# 4  2025-03-13 04:44:00      Bryan Adams   2025-03-06 2025-03-06           98
# 5  2025-03-14 10:07:00    Chappell Roan   2025-03-14 2025-03-14           77
# 6  2025-03-07 10:16:00          Doechii   2025-03-05 2025-03-05          752
# 7  2025-04-04 07:09:00       Ed Sheeran   2025-04-04 2025-04-04         1288
# 8  2025-05-03 09:45:00       Ed Sheeran   2025-05-01 2025-05-01           64
# 9  2025-03-05 17:13:00            Ghost   2025-03-05 2025-03-05          106
# 10 2025-02-05 18:33:00            Leony   2025-01-10 2025-01-10           59
# 11 2025-05-16 07:15:00       Lola Young   2025-05-16 2025-05-16           69
# 12 2025-02-24 12:19:00       Polo & Pan   2025-02-21 2025-02-21           77
# 13 2025-04-12 18:53:00     Rise Against   2025-04-03 2025-04-03           62
# 14 2025-02-08 19:18:00  The Blue Stones   2025-01-15 2025-01-15          116
# 15 2025-04-26 16:36:00      Tina Turner   2025-03-21 2025-03-21          101
# 16 2025-01-31 18:13:00      Tom Grennan   2025-01-29 2025-01-29           62
# 17 2025-01-17 11:36:00            Vella   2025-01-17 2025-01-17          155
# 18 2025-01-11 17:18:00     Youth Lagoon   2025-01-08 2025-01-08          201

# %%
# Sunburst chart

fig = px.sunburst(
    station_hits,
    path=['premiere_station', 'artist', 'title'],
    values='total_plays',
    color='premiere_station',
    color_discrete_map=station_colors,
    title='2025 Hits by Premiere Station and Popularity'
)

# Save the sunburst chart to HTML
fig.write_html(os.path.join(output_folder, "hit_sunburst_per_station.html"))

# %%
# 2025 Hits by premiere station and popularity
fig.update_layout(
    title='2025 Hits by premiere station and popularity',
    margin=dict(t=100, l=25, r=25, b=25),
    annotations=[
        dict(
            text=(
                "Hierarchy of segments:<br>"
                "- First level: station that played the hit first<br>"
                "- Second level: artist<br>"
                "- Third level: track title<br><br>"
                "The segment size represents the total number of plays<br>"
                "(across all stations)."
            ),
            showarrow=False,
            x=0.5, y=-0.1,
            xref="paper", yref="paper",
            align="center",
            font=dict(size=12)
        )
    ]
)

# Save the chart as HTML
fig.write_html(os.path.join(output_folder, "hit_sunburst_per_station_with_annotation.html"))

# %%
# Count the number of plays of each hit per station
plays_station = (
    df_hits
    .groupby(['artist', 'title', 'station'])
    .size()
    .reset_index(name='plays_station')
)
plays_station
# Out:
#           artist        title    station  plays_station
# 0   Abor & Tynna       Baller       Eska             80
# 1   Abor & Tynna       Baller  RMF MAXXX             60
# 2    Alex Warren     Ordinary    Czwórka              1
# 3    Alex Warren     Ordinary       Eska            417
# 4    Alex Warren     Ordinary    Jedynka              4
# ..           ...          ...        ...            ...
# 76         Vella  All My Love    Jedynka              6
# 77         Vella  All My Love  RMF MAXXX              4
# 78  Youth Lagoon  Speed Freak  Chillizet            143
# 79  Youth Lagoon  Speed Freak    Czwórka             55
# 80  Youth Lagoon  Speed Freak     Trójka              3
#
# [81 rows x 4 columns]

# %%
# First_overall: premiere station and time for each hit
sunburst_df = first_overall.merge(
    plays_station,
    on=['artist', 'title'],
    how='left'
)

# %%
# Sunburst chart - 2025 Hits: Premiere station → Artist → Title → All stations playing the song


fig = px.sunburst(
    sunburst_df,
    path=['premiere_station', 'artist', 'title', 'station'],
    values='plays_station',
    color='premiere_station',
    color_discrete_map=station_colors,
    title='2025 Hits: Premiere station → Artist → Title → All stations playing the song'
)

# Save to HTML
fig.write_html(os.path.join(output_folder, "hit_sunburst_full.html"))

# %%
# Number of plays of each hit per station (without premiere station on the last ring)
plays_station = df_hits.groupby(['artist', 'title', 'station']).size()

# Move indexes to columns
plays_station = (
    plays_station
    .rename_axis(['artist', 'title', 'station'])
    .reset_index()
)

# Name the column with values
plays_station.columns = ['artist', 'title', 'station', 'plays_station']

# %%
# Records where the premiere station information is missing

missing = station_hits_full[station_hits_full['premiere_station'].isna()]
print(missing[['artist', 'title', 'station', 'plays_station']].drop_duplicates())
# Out:
#                artist       title    station  plays_station
# 11      Black Sabbath    Paranoid  Antyradio             56
# 12      Black Sabbath    Paranoid    Jedynka              3
# 13      Black Sabbath    Paranoid     Trójka             11
# 14     Britney Spears       Lucky     VOX FM             80
# 21        Dina Summer  Girls Gang    Czwórka             78
# 44  Sabrina Carpenter       Taste       Eska            852
# 45  Sabrina Carpenter       Taste     RMF FM            198
# 46  Sabrina Carpenter       Taste  RMF MAXXX            704
# 47  Sabrina Carpenter       Taste     Trójka             36
# 48  Sabrina Carpenter       Taste        ZET            106

# %%
# Remove rows with missing premiere station information
station_hits_full = station_hits_full.dropna(subset=['premiere_station'])

# Remove rows with missing artist, title, or station information
station_hits_full = station_hits_full.dropna(subset=['artist', 'title', 'station'])

# %%
# 2025 Hits: Premiere station and further airplay in the network(excluding premiere station on last level)
fig = px.sunburst(
    station_hits_full,
    path=['premiere_station', 'artist', 'title', 'station'],
    values='plays_station',
    color='premiere_station',
    color_discrete_map=station_colors,
    title='2025 Hits: Premiere station and further airplay in the network'
)

# Save the sunburst chart as an HTML file
fig.write_html(os.path.join(output_folder, "hit_sunburst_without_premiere_on_level4.html"))

# %%
# Get the top 50 hits released in 2025 by total number of plays
hits2025 = (
    total_plays
    .merge(
        df_prem2025[['artists', 'title']],
        left_on=['artist', 'title'],
        right_on=['artists', 'title'],
        how='inner'
    )
    .sort_values('total_plays', ascending=False)
    .head(50)
    .reset_index(drop=True)
)

# %%
# Filter the music plays to include only the top 2025 hits
df_hits = df_music.merge(
    hits2025[['artist', 'title']],
    on=['artist', 'title'],
    how='inner'
)

# %%
# Find the first play of each 2025 hit per station
first_by_station = (
    df_hits
    .groupby(['artist', 'title', 'station'], as_index=False)
    .agg(first_play=('play_dt', 'min'))
)

# %%
# Merge with df_prem2025 to get release_date for each hit
fb = first_by_station.merge(
    df_prem2025[['artists', 'title', 'release_date']],
    left_on=['artist', 'title'],
    right_on=['artists', 'title'],
    how='left'
)

# Convert release_date to datetime and filter only valid (after release) first plays
fb['release_dt'] = pd.to_datetime(fb['release_date'])
fb = fb[fb['first_play'] >= fb['release_dt']]

# Find the premiere station and premiere time for each hit
first_overall = (
    fb
    .sort_values('first_play')
    .groupby(['artist', 'title'], as_index=False)
    .first()
    .rename(columns={'station': 'premiere_station', 'first_play': 'premiere_time'})
)

# %%
# Count number of plays for each hit per station
plays_station = (
    df_hits
    .groupby(['artist', 'title', 'station'])
    .size()
    .rename_axis(['artist', 'title', 'station'])
    .reset_index(name='plays_station')
)

# Exclude the premiere station
plays_excl = plays_station.merge(
    first_overall[['artist', 'title', 'premiere_station']],
    on=['artist', 'title'],
    how='left'
)
plays_excl = plays_excl[plays_excl['station'] != plays_excl['premiere_station']]

# %%
# Merge with total plays for each hit
station_hits_full = plays_excl.merge(
    total_plays,
    on=['artist', 'title'],
    how='left'
)

station_hits_clean = station_hits_full.dropna(
    subset=['premiere_station','artist', 'title', 'station']
)



# Create a sunburst chart with a max depth of 2 levels
fig = px.sunburst(
    station_hits_clean,
    path=['premiere_station', 'artist', 'title', 'station'],
    values='plays_station',
    color='premiere_station',
    color_discrete_map=station_colors,
    title='2025 Hits: Premiere Station and Further Airplay'
)

fig.update_traces(maxdepth=2)  # Limit the sunburst to 2 levels

fig.write_html(os.path.join(output_folder, "hit_sunburst_full_clean.html"))

# %%
# Top 5 artists for each station

# Group by station and artist, count plays
artist_station = (
    df_music
    .groupby(['station', 'artist'])
    .size()
    .reset_index(name='plays')
)

# Select the top 5 artists for each station
top5 = (
    artist_station
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
    .reset_index(drop=True)
)

# %%
# Top 5 Artists in each radio station

fig = px.bar(
    top5,
    x='plays',
    y='artist',
    color='station',
    color_discrete_map=station_colors,
    orientation='h',
    facet_row='station',
    height=320 * top5['station'].nunique(),
    title='Top 5 Artists in each radio station',
    labels={'plays': 'Number of Plays', 'artist': 'Artist'}
)

fig.update_yaxes(categoryorder='total ascending')
fig.update_layout(
    showlegend=False,
    margin=dict(l=120, t=70)
)

fig.add_annotation(
    text="Each panel shows the 5 most frequently played artists for a given radio station.<br>Panel colors correspond to the station colors used in the report.",
    xref="paper", yref="paper",
    x=0.5, y=1.10, showarrow=False,
    font=dict(size=13),
    align="center"
)

# Save the chart as HTML
fig.write_html(os.path.join(output_folder, "top5_artists_per_radio.html"))

# %%
# Count how many times each artist was played in each station
artist_station = (
    df_music
    .groupby(['station', 'artist'])
    .size()
    .reset_index(name='plays')
)

# Select the top 5 most popular artists for each radio station
top5_per_radio = (
    artist_station
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
    .reset_index(drop=True)
)

print(top5_per_radio)
# Out:
#            station                 artist  plays
# 0        Antyradio                    Hey   1722
# 1        Antyradio                   Kult   1705
# 2        Antyradio                Perfect   1491
# 3        Antyradio  Red Hot Chili Peppers   1452
# 4        Antyradio              Lady Pank   1408
# ..             ...                    ...    ...
# 60  Złote Przeboje              Lady Pank   2096
# 61  Złote Przeboje                 Maanam   1837
# 62  Złote Przeboje     Elektryczne Gitary   1770
# 63  Złote Przeboje                   Bajm   1564
# 64  Złote Przeboje                  Kombi   1559
#
# [65 rows x 3 columns]

# %%
# Count in how many different stations each artist appears in the top 5
artist_count = top5_per_radio['artist'].value_counts()
unique_artists = artist_count[artist_count == 1].index.tolist()

# Add a column indicating whether the artist is unique to a single station's top 5
top5_per_radio['unique'] = top5_per_radio['artist'].isin(unique_artists)

# %%
# Top 5 artists in each radio station (unique highlighted in bold)

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Make artist name bold in HTML if unique to a single station's top 5
def bold_if_unique(row):
    return f"<b>{row['artist']}</b>" if row['unique'] else row['artist']

top5_per_radio['artist_fmt'] = top5_per_radio.apply(bold_if_unique, axis=1)

# To keep order, set category for artist_fmt:
artist_order = (
    top5_per_radio
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')['artist_fmt']
    .apply(list)
    .explode()
    .unique()
)

# Create a faceted bar chart with bolded unique artists
fig = px.bar(
    top5_per_radio,
    x='plays',
    y='artist_fmt',
    color='station',
    color_discrete_map=station_colors,
    orientation='h',
    facet_row='station',
    height=320 * top5_per_radio['station'].nunique(),
    title='Top 5 artists in each radio station (unique highlighted in bold)',
    labels={'plays': 'Number of Plays', 'artist_fmt': 'Artist'}
)

fig.update_yaxes(categoryorder='total ascending')

# Enable rendering HTML labels
fig.update_traces(texttemplate="%{y}", textposition="auto", textfont_size=14)

# Add detailed hover text for clarity
fig.update_traces(
    hovertemplate='<b>Artist:</b> %{y}<br>Number of plays: %{x}<extra></extra>'
)

# Add annotation explaining the bold formatting
fig.add_annotation(
    text=(
        "Each panel shows the 5 most played artists for a given radio station.<br>"
        "<b>Bold name</b> – artist appears only in this station's top 5."
    ),
    xref="paper", yref="paper",
    x=0.5, y=1.11, showarrow=False,
    font=dict(size=13),
    align="center"
)

# Save the chart as HTML
fig.write_html(os.path.join(output_folder, "top5_artists_per_radio_highlight.html"))

# %%
# Create output folders for top 5 artists and tracks per station
os.makedirs(os.path.join(output_folder, "top5_artists_per_radio"), exist_ok=True)
os.makedirs(os.path.join(output_folder, "top5_tracks_per_radio"), exist_ok=True)

# %%
# Group by station and artist (number of plays)
artist_station = (
    df_music
    .groupby(['station', 'artist'])
    .size()
    .reset_index(name='plays')
)

# Group by station and track title (number of plays)
track_station = (
    df_music
    .groupby(['station', 'title'])
    .size()
    .reset_index(name='plays')
)

# Top 5 artists for each station
top5_artists = (
    artist_station
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
    .reset_index(drop=True)
)

# Top 5 tracks for each station
top5_tracks = (
    track_station
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
    .reset_index(drop=True)
)

# %%
# Unique artists: artists who appear in the top 5 for only one station
unique_artists = top5_artists['artist'].value_counts()
unique_artists = unique_artists[unique_artists == 1].index.tolist()

# Unique tracks: tracks that appear in the top 5 for only one station
unique_tracks = top5_tracks['title'].value_counts()
unique_tracks = unique_tracks[unique_tracks == 1].index.tolist()

# Mark unique artists and tracks in the top 5 lists
top5_artists['unique'] = top5_artists['artist'].isin(unique_artists)
top5_tracks['unique'] = top5_tracks['title'].isin(unique_tracks)

# %%
# Top 5 artists - one file per radio station
for station in top5_artists['station'].unique():
    df_station = top5_artists[top5_artists['station'] == station].sort_values('plays', ascending=True)
    # Bold the name if unique
    df_station['artist_fmt'] = df_station.apply(
        lambda row: f"<b>{row['artist']}</b>" if row['unique'] else row['artist'],
        axis=1
    )
    fig = px.bar(
        df_station,
        x='plays',
        y='artist_fmt',
        orientation='h',
        color_discrete_sequence=[station_colors.get(station, "#666666")],
        title=f'Top 5 Artists in {station}',
        labels={'plays': 'Number of Plays', 'artist_fmt': 'Artist'}
    )
    fig.update_yaxes(categoryorder='total ascending')
    fig.update_layout(showlegend=False)
    fig.write_html(os.path.join(output_folder, "top5_artists_per_radio", f"top5_artists_{station}.html"))

# Top 5 tracks - one file per radio station
for station in top5_tracks['station'].unique():
    df_station = top5_tracks[top5_tracks['station'] == station].sort_values('plays', ascending=True)
    # Bold the title if unique
    df_station['title_fmt'] = df_station.apply(
        lambda row: f"<b>{row['title']}</b>" if row['unique'] else row['title'],
        axis=1
    )
    fig = px.bar(
        df_station,
        x='plays',
        y='title_fmt',
        orientation='h',
        color_discrete_sequence=[station_colors.get(station, "#666666")],
        title=f'Top 5 Tracks in {station}',
        labels={'plays': 'Number of Plays', 'title_fmt': 'Track Title'}
    )
    fig.update_yaxes(categoryorder='total ascending')
    fig.update_layout(showlegend=False)
    fig.write_html(os.path.join(output_folder, "top5_tracks_per_radio", f"top5_tracks_{station}.html"))

# %%
top5_tracks
# Out:
#            station                      title  plays  unique
# 0        Antyradio      Twoje Oczy Lubia Mnie    273    True
# 1        Antyradio  Nabijam Lufę (Feat. Hiob)    251    True
# 2        Antyradio                  Favourite    244    True
# 3        Antyradio              Rock N'roller    243    True
# 4        Antyradio                    Chłopcy    240    True
# ..             ...                        ...    ...     ...
# 60  Złote Przeboje                      Maria    382    True
# 61  Złote Przeboje                    Tonight    328    True
# 62  Złote Przeboje             99 Luftballons    323    True
# 63  Złote Przeboje                  Zakrecona    315    True
# 64  Złote Przeboje         Dziewczyna Szamana    313    True
#
# [65 rows x 4 columns]

# %%
# Group by station, title, and artist; count plays
track_station_artist = (
    df_music
    .groupby(['station', 'title', 'artist'])
    .size()
    .reset_index(name='plays')
)

# Select the top 5 tracks (by play count) for each station
top5_tracks = (
    track_station_artist
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
    .reset_index(drop=True)
)

# %%
import os

# Create the output folder for unique track reports
os.makedirs(os.path.join(output_folder, "unique"), exist_ok=True)

# Create a track identifier as (artist – title)
df_music['track_id'] = df_music['artist'] + " - " + df_music['title']

# Library size per radio (number of unique tracks)
library_size = (
    df_music.groupby('station')['track_id'].nunique().reset_index(name='Number of Tracks')
)

# Number of tracks unique to each radio station
# - Count in how many different stations each track was played
track_radio_count = (
    df_music.groupby('track_id')['station'].nunique().reset_index(name='station_count')
)

# - Keep only tracks played in exactly one station
unique_tracks = track_radio_count[track_radio_count['station_count'] == 1]['track_id']

# - Count the number of such unique tracks per station
unique_per_station = (
    df_music[df_music['track_id'].isin(unique_tracks)]
    .groupby('station')['track_id'].nunique()
    .reset_index(name='Unique Tracks')
)

# %%
# Size of each station's track library and the number of tracks unique to each station

# Library size per station
fig1 = px.bar(
    library_size.sort_values('Number of Tracks', ascending=False),
    x='station', y='Number of Tracks',
    color='station',
    color_discrete_map=station_colors,
    title='Library Size: Number of Unique Tracks per Station',
    text='Number of Tracks'
)
fig1.update_layout(showlegend=False)
fig1.write_html(os.path.join(output_folder, "unique", "library_size_per_station.html"))

# Number of unique tracks per station
fig2 = px.bar(
    unique_per_station.sort_values('Unique Tracks', ascending=False),
    x='station', y='Unique Tracks',
    color='station',
    color_discrete_map=station_colors,
    title='Number of Unique Tracks in Each Station\'s Library<br><span style="font-size:13px">(track = artist + title, uniqueness: not played on any other station)</span>',
    text='Unique Tracks'
)
fig2.update_layout(showlegend=False)
fig2.write_html(os.path.join(output_folder, "unique", "unique_tracks_per_station.html"))

display(unique_per_station)
# Out:
#            station  Unique Tracks
# 0        Antyradio           4426
# 1        Chillizet           5779
# 2          Czwórka          16125
# 3           Dwójka          26405
# 4             Eska            915
# 5          Jedynka          14073
# 6      RMF Classic           3241
# 7           RMF FM            322
# 8        RMF MAXXX            876
# 9           Trójka          18241
# 10          VOX FM           2214
# 11             ZET            512
# 12  Złote Przeboje            371

# %%
# Export tables of tracks that are unique to each station (not played anywhere else)

# Create the folder for unique track tables per station
os.makedirs(os.path.join(output_folder, "unique", "tracks_per_station"), exist_ok=True)

# For each station, export a table of unique tracks (artist + title), i.e. tracks played only in this station
for station in df_music['station'].unique():
    df_uni = (
        df_music[
            (df_music['station'] == station) &
            (df_music['track_id'].isin(unique_tracks))
        ][['artist', 'title']]
        .drop_duplicates()
        .sort_values(['artist', 'title'])
    )
    df_uni.to_html(
        os.path.join(output_folder, "unique", "tracks_per_station", f"unique_tracks_{station}.html"),
        index=False,
        encoding="utf-8"
    )

# %%
# Create a track ID (artist – title)
df_music['track_id'] = df_music['artist'] + " - " + df_music['title']

# Count the number of plays for each unique track in each station
unique_plays = (
    df_music[df_music['track_id'].isin(unique_tracks)]
    .groupby(['station', 'artist', 'title', 'track_id'])
    .size()
    .reset_index(name='plays')
)

# %%
# For each station, select the top 5 unique tracks by play count
top5_unique_per_station = (
    unique_plays
    .sort_values(['station', 'plays'], ascending=[True, False])
    .groupby('station')
    .head(5)
    .reset_index(drop=True)
)

# %%
# Top 5 most played unique tracks in radio station

# Create output folder for top 5 unique tracks per station
os.makedirs(os.path.join(output_folder, "unique", "top5_unique_per_station"), exist_ok=True)

# For each station, plot the top 5 unique tracks (artist – title)
for station in top5_unique_per_station['station'].unique():
    df_station = top5_unique_per_station[top5_unique_per_station['station'] == station].sort_values('plays', ascending=True)
    # Y axis: Artist – Title
    df_station['track_full'] = df_station['artist'] + " - " + df_station['title']
    fig = px.bar(
        df_station,
        x='plays',
        y='track_full',
        orientation='h',
        color_discrete_sequence=[station_colors.get(station, "#666666")],
        title=f"Top 5 most played unique tracks in {station}",
        labels={'plays': 'Number of Plays', 'track_full': 'Track (Artist – Title)'}
    )
    fig.update_yaxes(categoryorder='total ascending')
    fig.update_layout(showlegend=False)
    fig.add_annotation(
        text="Top 5 tracks played exclusively in this radio station.<br>Sorted by number of plays.",
        xref="paper", yref="paper",
        x=0.5, y=1.12, showarrow=False,
        font=dict(size=13),
        align="center"
    )
    fig.write_html(os.path.join(output_folder, "unique", "top5_unique_per_station", f"top5_unique_{station}.html"))
